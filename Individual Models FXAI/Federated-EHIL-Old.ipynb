# %% [markdown]
# ## Imports

# %%
from __future__ import print_function

import tensorflow as tf
import tensorflow_federated as tff
import numpy as np
import collections
from tensorflow.keras.models import load_model

# From EHIL


import keras
from keras.layers.convolutional import ( Conv2D, MaxPooling2D, AveragePooling2D)
from keras.layers import (    Input,    Activation,    Dense,    Flatten)
from keras.layers import add
from keras.layers import LayerNormalization

from keras.regularizers import l2
from keras import backend as K
from keras.models import Model

from keras.preprocessing.image import ImageDataGenerator
from keras.callbacks import ReduceLROnPlateau, CSVLogger, EarlyStopping
from keras.callbacks import ModelCheckpoint, LearningRateScheduler
from keras.utils import np_utils

import os
import numpy as np

from sklearn.model_selection import train_test_split
# Out:
# 2023-06-10 13:28:54.853707: I tensorflow/core/util/port.cc:110] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2023-06-10 13:28:54.904032: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-06-10 13:28:55.215712: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-06-10 13:28:55.216741: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
summary_writer_h1 = tf.summary.create_file_writer('logs/H1')
summary_writer_h2 = tf.summary.create_file_writer('logs/H2')
summary_writer_h3 = tf.summary.create_file_writer('logs/H3')

# %% [markdown]
# ## Config

# %%
# Config
save_dir = os.path.join(os.getcwd(), 'Log')
Folder_Name = 'Videos_Database_20_Robot'

Type = 'WebCam'
##############################################################################

Process_Image_Flag = True
Robust_Flag = True

img_rows, img_cols = 256,256
img_rows, img_cols = 50,50

img_channels = 3
BATCH_SIZE = 20
nb_epoch = 100

Cup_Type = 'Big'
if Cup_Type == 'Medium':
    nb_classes = 9
if Cup_Type == 'Big':
    nb_classes = 10
if Cup_Type == 'Small':
    nb_classes = 7   



PHASE_CLASSES = 4
STATE_CLASSES = 10

# %% [markdown]
# ## Load Data

# %%
NPZ_Name = 'Data/Videos_Database_20_Robot_WebCam_50_overall_database.npz'
Database_Used = np.load(NPZ_Name)
Sessions = Database_Used['Session']
X_train = Database_Used['X_train']
Y_train_State = Database_Used['Y_train_State']
Y_train_Phase = Database_Used['Y_train_Context']
Y_train_Regress=Database_Used['Y_train_Regress']

# %%
# create a list of the unique sessions
client_ids = np.unique(Sessions)

# %%
def create_tf_dataset(client_ids, Database_used_col, categorical, categories):
  train_datasets = []
  test_datasets = []
  for session in client_ids:  
    # find the indices of the current session in the Sessions column of Database_Used
    session_indices = np.where(Sessions == session)[0]

    # get the X_train data for the current session
    session_X = Database_Used['X_train'][session_indices]
    # grab the training data for the necessary hierarchy
    session_Y = Database_Used[Database_used_col][session_indices]
    # if using categorical data, reshape the data for the model into one-hot encoded
    if categorical==True:
      session_Y = np_utils.to_categorical(session_Y, categories)
    # create train/test split
    X_train, X_test, Y_train, Y_test = train_test_split(session_X, session_Y, test_size=0.2, random_state=100)
    # Make into tf dataset
    train_dataset = tf.data.Dataset.from_tensor_slices((X_train,Y_train))
    test_dataset = tf.data.Dataset.from_tensor_slices((X_test, Y_test))
    # Add to our list of datasets
    train_datasets.append([session,train_dataset])
    test_datasets.append([session,test_dataset])
  return train_datasets, test_datasets

# %%
phase_train_datasets, phase_test_datasets = create_tf_dataset(client_ids, 'Y_train_Context', True, PHASE_CLASSES)
state_train_datasets, state_test_datasets = create_tf_dataset(client_ids, 'Y_train_State', True, STATE_CLASSES)
regress_train_datasets, regress_test_datasets = create_tf_dataset(client_ids, 'Y_train_Regress', False, None)

# %%
def make_client_data(datasets):
  client_data = {}
  # loop through the datasets
  for dataset in datasets:
      # get the session name
      session = dataset[0]
      
      # get the session data
      session_data = dataset[1]
      
      # add the session data to the client_data dictionary
      client_data[session] = session_data
  return client_data

# %%
# Make everything into a map for creating ClientData objects necessary for TFF federated learning

phase_train_client_data = make_client_data(phase_train_datasets)
phase_test_client_data = make_client_data(phase_test_datasets)
state_train_client_data = make_client_data(state_train_datasets)
state_test_client_data = make_client_data(state_test_datasets)
regress_train_client_data = make_client_data(regress_train_datasets)
regress_test_client_data = make_client_data(regress_test_datasets)

# %%
client_ids = list(client_ids)

# %% [markdown]
# ## Setup Federated Data

# %%
def make_federated_data(client_data, client_ids):
  # Need a function to get the client data in order to make ClientData object
  def get_client_dataset(client_id):
    return client_data[client_id]

  # use tff to create ClientData object from our training data
  federated_data = tff.simulation.datasets.ClientData.from_clients_and_tf_fn(client_ids, get_client_dataset)

  return federated_data

# %%
phase_train_federated_data = make_federated_data(phase_train_client_data, client_ids)
phase_test_federated_data = make_federated_data(phase_test_client_data, client_ids)
state_train_federated_data = make_federated_data(state_train_client_data, client_ids)
state_test_federated_data = make_federated_data(state_test_client_data, client_ids)
regress_train_federated_data = make_federated_data(regress_train_client_data, client_ids)
regress_test_federated_data = make_federated_data(regress_test_client_data, client_ids)

# %%
type(phase_train_federated_data)
# Out:
# tensorflow_federated.python.simulation.datasets.client_data.ConcreteClientData

# %%
NUM_CLIENTS = 10
BATCH_SIZE = 20

def preprocess(dataset, num_classes):
    def batch_format_fn(image, label):
        """Prepare a batch of data and return a (features, label) tuple."""
        batch_size = tf.shape(image)[0]  # Get the current batch size
        return (tf.reshape(image, [batch_size, 50, 50, 3]),
                tf.reshape(label, [batch_size, num_classes]))

    return dataset.batch(BATCH_SIZE).map(batch_format_fn)

def preprocess_federated_data(federated_data, num_classes):
  client_ids = sorted(federated_data.client_ids)[:NUM_CLIENTS]
  federated_data = [preprocess(federated_data.create_tf_dataset_for_client(x), num_classes)
                          for x in client_ids]
  return federated_data

# %%
phase_train = preprocess_federated_data(phase_train_federated_data, PHASE_CLASSES)
state_train = preprocess_federated_data(state_train_federated_data, STATE_CLASSES)
regress_train = preprocess_federated_data(regress_train_federated_data, 1)

# %%
state_train[0].element_spec
# Out:
# (TensorSpec(shape=(None, 50, 50, 3), dtype=tf.float32, name=None),
#  TensorSpec(shape=(None, 10), dtype=tf.float32, name=None))

# %% [markdown]
# ## Setup EHIL Models

# %% [markdown]
# ### Functions

# %%
###############################################################################
'''
Functions
'''
###############################################################################

from keras.initializers import glorot_uniform

def lr_schedule(epoch):
    '''
    epoch: number of epochs for model training
    lr: learning rate
    ''' 
    lr = 1e-3
    if epoch > 160:
        lr *= 0.5e-3
    elif epoch > 120:
        lr *= 1e-3
    elif epoch > 80:
        lr *= 1e-2
    elif epoch > 40:
        lr *= 1e-1
    print('Learning rate: ', lr)
    return lr



def Conv_bn_relu(infor, **conv_params):
    '''
    Build conv -> BN -> relu block
    '''
    filters = conv_params["filters"]
    kernel_size = conv_params["kernel_size"]
    strides = conv_params.setdefault("strides", (1, 1))
    kernel_initializer = conv_params.setdefault("kernel_initializer", "he_normal")
    padding = conv_params.setdefault("padding", "same")
    kernel_regularizer = conv_params.setdefault("kernel_regularizer", l2(1.e-4))


    conv = Conv2D(filters=filters, kernel_size=kernel_size,
                  strides=strides, padding=padding,
                  kernel_initializer=kernel_initializer,
                  kernel_regularizer=kernel_regularizer)(infor)
    
    
    norm = LayerNormalization(axis=CHANNEL_AXIS)(conv)
    out = Activation("relu")(norm)

    return out 


#Reference: http://arxiv.org/pdf/1603.05027v2.pdf
def Bn_relu_conv(infor,**conv_params):
    '''
    Build a BN -> relu -> conv block.
    '''
    filters = conv_params["filters"]
    kernel_size = conv_params["kernel_size"]
    strides = conv_params.setdefault("strides", (1, 1))
    kernel_initializer = conv_params.setdefault("kernel_initializer", "he_normal")
    padding = conv_params.setdefault("padding", "same")
    kernel_regularizer = conv_params.setdefault("kernel_regularizer", l2(1.e-4))

    norm = LayerNormalization(axis=CHANNEL_AXIS)(infor)

    activation = Activation("relu")(norm)
        
    out = Conv2D(filters=filters, kernel_size=kernel_size,
                      strides=strides, padding=padding,
                      kernel_initializer=kernel_initializer,
                      kernel_regularizer=kernel_regularizer)(activation)

    return out



def basic_block(BlockIn, filters, init_strides=(1, 1), is_first_block_of_first_layer=False):
    '''
    Basic 3 X 3 convolution blocks
    '''

    if is_first_block_of_first_layer:
        conv1 = Conv2D(filters=filters, kernel_size=(3, 3),
                       strides=init_strides,
                       padding="same",
                       kernel_initializer="he_normal",
                       kernel_regularizer=l2(1e-4))(BlockIn)
    else:
        conv1 = Bn_relu_conv(infor = BlockIn,filters=filters, kernel_size=(3, 3),
                              strides=init_strides)

    residual = Bn_relu_conv(infor = conv1,filters=filters, kernel_size=(3, 3))


    input_shape = K.int_shape(BlockIn)
    residual_shape = K.int_shape(residual)
    
    # stride should be set properly and match  (width, height) of residual
    stride_width = int(round(input_shape[ROW_AXIS] / residual_shape[ROW_AXIS]))
    stride_height = int(round(input_shape[COL_AXIS] / residual_shape[COL_AXIS]))
    
    
    equal_channels = input_shape[CHANNEL_AXIS] == residual_shape[CHANNEL_AXIS]

    
    if stride_width > 1 or stride_height > 1 or not equal_channels:
        shortcut = Conv2D(filters=residual_shape[CHANNEL_AXIS],
                          kernel_size=(1, 1),
                          strides=(stride_width, stride_height),
                          padding="valid",
                          kernel_initializer="he_normal",
                          kernel_regularizer=l2(0.0001))(BlockIn)        
    else:
        shortcut = BlockIn
    
    # Adds a shortcut between input and residual block
    return add([shortcut, residual])


def buildmodel(input_shape, num_outputs, Regress_Flag):
        '''

        input_shape: (nb_channels, nb_rows, nb_cols)
        num_outputs:  number of outputs at final softmax layer
        Regress_Flag: classify or regress

        '''

        global ROW_AXIS
        global COL_AXIS
        global CHANNEL_AXIS
        
        # if K.image_data_format() == 'channels_last':
        
        #     ROW_AXIS = 1; COL_AXIS = 2;  CHANNEL_AXIS = 3
        # else:
        #     CHANNEL_AXIS = 1; ROW_AXIS = 2; COL_AXIS = 3        

        if tf.keras.backend.image_data_format() == 'channels_last':
            ROW_AXIS = 1
            COL_AXIS = 2
            CHANNEL_AXIS = 3
        else:
            CHANNEL_AXIS = 1
            ROW_AXIS = 2
            COL_AXIS = 3

        
        
        if len(input_shape) != 3:
            raise Exception("Input shape should be a tuple (nb_channels, nb_rows, nb_cols)")

        # Permute dimension order if necessary
        if K.image_data_format() == 'channels_last':
        #if K.image_dim_ordering() == 'tf':

            input_shape = (input_shape[1], input_shape[2], input_shape[0])

        input = Input(shape=input_shape, name='main_input')
        conv1 = Conv_bn_relu(input, filters=64, kernel_size=(7, 7), strides=(2, 2))
        pool1 = MaxPooling2D(pool_size=(3, 3), strides=(2, 2), padding="same", name = "conv_pool1")(conv1)

        block = pool1
        filters = 64
        for i, r in enumerate([2,2,2,2]):
            '''
            residual block with repeating bottleneck blocks
            '''

            is_first_layer=(i == 0)
            for i in range(r):
                init_strides = (1, 1)
                if i == 0 and not is_first_layer:
                    init_strides = (2, 2)
                block = basic_block(BlockIn = block, filters=filters, init_strides=init_strides,
                                       is_first_block_of_first_layer=(is_first_layer and i == 0))
                
            filters *= 2

        # Last activation
    
        norm = LayerNormalization(axis=CHANNEL_AXIS)(block)
        block = Activation("relu")(norm)

        # classifier block
        block_shape = K.int_shape(block)
        pool2_out = AveragePooling2D(pool_size=(block_shape[ROW_AXIS], block_shape[COL_AXIS]),
                                 strides=(1, 1), name = "conv_final")(block)
        
        #flatten1 = keras.layers.GlobalAveragePooling2D(name = "GAP")(pool2)
        #out = keras.layers.Dense(num_outputs,activation='softmax')(pooled)

        flatten1 = Flatten( name = "Flatten")(pool2_out)

        flatten1 = Dense(128, activation='relu',name = "Flatten2")(flatten1)

        if Regress_Flag == False:
            
            dense = Dense(units=num_outputs, kernel_initializer="he_normal",
                      activation="softmax", name = "Dense_layer")(flatten1)
        else:
            dense = Dense(units=1, activation='linear', kernel_initializer=glorot_uniform(seed=0))(flatten1)
            
            #dense = Dense(units=1, kernel_initializer="he_normal", activation="linear", name = "Dense_layer")(flatten1)
  
        model = Model(inputs=input, outputs=dense)
        return model


def learn_model(oldmodel,nb_classes,Transfer_Type,summary=False): 

    base_model = oldmodel
    
    if Transfer_Type == 'Classification':
        intermediate_layer_model = Model(inputs=base_model.input,outputs=base_model.get_layer("conv_final").output)

    if Transfer_Type == 'Regression':
        #intermediate_layer_model = Model(inputs=base_model.input,outputs=base_model.get_layer("Flatten1").output)
        intermediate_layer_model = Model(inputs=base_model.input,outputs=base_model.get_layer("Dense_Classification").output)
    
    x = intermediate_layer_model(base_model.input)
    if nb_classes >1:
        x = keras.layers.GlobalAveragePooling2D()(x)# 添加全局平均池化层 
    x = Dense(128, activation='relu')(x)
    x = Dense(64, activation='relu')(x)
    
    
    if Transfer_Type == 'Classification':
        dense = Dense(units=nb_classes, kernel_initializer="he_normal",
                  activation="softmax", name = "Dense_Classification")(x)
    if Transfer_Type == 'Regression':
        dense = Dense(units=1, activation='linear', name = "Dense_Regression", kernel_initializer=glorot_uniform(seed=0))(x)

    model = Model(inputs=base_model.input, outputs=dense)
    
    
    # show summary if specified
    if summary==True : 
        model.summary()

    if Transfer_Type == 'Classification':
        # choose the optimizer 
        #optimizer = keras.optimizers.Adam()
        model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
        
    if Transfer_Type == 'Regression':
        model.compile(loss = 'mean_squared_error', optimizer = 'adam', metrics=['mse'])

    return model

# %% [markdown]
# ### H1

# %%
'''
Prepare to train model H1
'''
# nb_classes = 4 
# Model_Type = 'Phase'

def build_h1_model():
  return buildmodel((img_channels, img_rows, img_cols), PHASE_CLASSES,False)

h1_model = build_h1_model()
h1_example = build_h1_model()

BUILD_FN = build_h1_model
INPUT_SPEC = phase_train[0].element_spec

# %% [markdown]
# ### H2

# %%
h2_template = learn_model(h1_example, STATE_CLASSES, 'Classification',False)

def build_h2_model():
  return tf.keras.models.clone_model(h2_template)
  # return buildmodel((img_channels, img_rows, img_cols), STATE_CLASSES,False)

h2_example = build_h2_model()

# %% [markdown]
# ### H3

# %%
h3_template = learn_model(h2_example, 1, 'Regression',False)

def build_h3_model():
  return tf.keras.models.clone_model(h3_template)

# %% [markdown]
# ## Setup Federated Learning

# %% [markdown]
# ### H1

# %%
def model_fn_h1():
  model = build_h1_model()
  return tff.learning.models.from_keras_model(
      model,
      input_spec=phase_train[0].element_spec,
      loss=tf.keras.losses.CategoricalCrossentropy(),
      metrics=[tf.keras.metrics.Accuracy()])

# %%
@tff.tf_computation
def server_init_h1():
  model = model_fn_h1()
  return model.trainable_variables

# %%
@tff.federated_computation
def initialize_fn_h1():
  return tff.federated_value(server_init_h1(), tff.SERVER)

# %%
@tf.function
def client_update_h1(model, dataset, server_weights, client_optimizer):
  """Performs training (using the server model weights) on the client's dataset."""
  # Initialize the client model with the current server weights.
  client_weights = model.trainable_variables
  # Assign the server weights to the client model.
  tf.nest.map_structure(lambda x, y: x.assign(y),
                        client_weights, server_weights)

  # Use the client_optimizer to update the local model.
  for batch in dataset:
    with tf.GradientTape() as tape:
      # Compute a forward pass on the batch of data
      outputs = model.forward_pass(batch)

    # Compute the corresponding gradient
    grads = tape.gradient(outputs.loss, client_weights)
    grads_and_vars = zip(grads, client_weights)

    # Apply the gradient using a client optimizer.
    client_optimizer.apply_gradients(grads_and_vars)

  return client_weights

# %%
@tf.function
def server_update_h1(model, mean_client_weights):
  """Updates the server model weights as the average of the client model weights."""
  model_weights = model.trainable_variables
  # Assign the mean client weights to the server model.
  tf.nest.map_structure(lambda x, y: x.assign(y),
                        model_weights, mean_client_weights)
  return model_weights

# %%
h1_fed = model_fn_h1()
tf_dataset_type_h1 = tff.SequenceType(h1_fed.input_spec)

# %%
str(tf_dataset_type_h1)
# Out:
# '<float32[?,50,50,3],float32[?,4]>*'

# %%
model_weights_type_h1 = h1_fed.trainable_variables
# Assuming model_weights_type is a list of trainable variables
model_weights_type_h1 = [v for v in model_weights_type_h1]

model_weights_type_h1 = tff.to_type([tf.TensorSpec.from_tensor(v.value()) for v in model_weights_type_h1])

# %%
@tff.tf_computation(tf_dataset_type_h1, model_weights_type_h1)
def client_update_fn_h1(tf_dataset, server_weights):
  model = model_fn_h1()
  client_optimizer = tf.keras.optimizers.SGD(learning_rate=0.01)
  return client_update_h1(model, tf_dataset, server_weights, client_optimizer)
# Out:
# 2023-06-10 12:57:08.936132: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_5' with dtype float and shape [?,1,1,512]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_5}}]]
# 2023-06-10 12:57:08.936292: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_6' with dtype float and shape [?,2,2,512]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_6}}]]
# 2023-06-10 12:57:08.936342: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_7' with dtype float and shape [?,2,2,512]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_7}}]]
# 2023-06-10 12:57:08.936385: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_8' with dtype float and shape [512]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_8}}]]
# 2023-06-10 12:57:08.936427: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_9' with dtype float and shape [?,2,2,512]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_9}}]]
# 2023-06-10 12:57:08.936470: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_10' with dtype float and shape [512]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_10}}]]
# 2023-06-10 12:57:08.936531: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_11' with dtype float and shape [1,?,512,1]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_11}}]]
# 2023-06-10 12:57:08.936592: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_19' with dtype float and shape [?,2,2,512]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_19}}]]
# 2023-06-10 12:57:08.936627: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_20' with dtype float and shape [?,2,2,512]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_20}}]]
# 2023-06-10 12:57:08.936666: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_21' with dtype float and shape [?,2,2,512]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_21}}]]
# 2023-06-10 12:57:08.936698: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_22' with dtype float and shape [?,2,2,512]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_22}}]]
# 2023-06-10 12:57:08.936730: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_24' with dtype float and shape [?,2,2,512]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_24}}]]
# 2023-06-10 12:57:08.936761: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_25' with dtype float and shape [512]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_25}}]]
# 2023-06-10 12:57:08.936807: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_26' with dtype float and shape [?,2,2,512]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_26}}]]
# 2023-06-10 12:57:08.936839: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_27' with dtype float and shape [512]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_27}}]]
# 2023-06-10 12:57:08.936871: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_28' with dtype float and shape [1,?,512,1]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_28}}]]
# 2023-06-10 12:57:08.936902: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_36' with dtype float and shape [?,2,2,512]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_36}}]]
# 2023-06-10 12:57:08.936933: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_37' with dtype float and shape [?,2,2,512]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_37}}]]
# 2023-06-10 12:57:08.936992: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_39' with dtype float and shape [?,2,2,512]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_39}}]]
# 2023-06-10 12:57:08.937065: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_40' with dtype float and shape [512]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_40}}]]
# 2023-06-10 12:57:08.937099: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_41' with dtype float and shape [?,2,2,512]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_41}}]]
# 2023-06-10 12:57:08.937156: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_42' with dtype float and shape [512]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_42}}]]
# 2023-06-10 12:57:08.937228: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_43' with dtype float and shape [1,?,512,1]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_43}}]]
# 2023-06-10 12:57:08.937270: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_51' with dtype float and shape [?,2,2,512]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_51}}]]
# 2023-06-10 12:57:08.937301: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_52' with dtype float and shape [?,2,2,512]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_52}}]]
# 2023-06-10 12:57:08.937332: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_53' with dtype float and shape [?,4,4,256]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_53}}]]
# 2023-06-10 12:57:08.937406: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_55' with dtype float and shape [?,2,2,512]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_55}}]]
# 2023-06-10 12:57:08.937441: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_57' with dtype float and shape [?,2,2,512]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_57}}]]
# 2023-06-10 12:57:08.937504: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_58' with dtype float and shape [512]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_58}}]]
# 2023-06-10 12:57:08.937562: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_59' with dtype float and shape [?,2,2,512]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_59}}]]
# 2023-06-10 12:57:08.937596: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_60' with dtype float and shape [512]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_60}}]]
# 2023-06-10 12:57:08.937669: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_61' with dtype float and shape [1,?,512,1]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_61}}]]
# 2023-06-10 12:57:08.937701: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_69' with dtype float and shape [?,2,2,512]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_69}}]]
# 2023-06-10 12:57:08.937734: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_70' with dtype float and shape [?,4,4,256]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_70}}]]
# 2023-06-10 12:57:08.937800: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_72' with dtype float and shape [?,4,4,256]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_72}}]]
# 2023-06-10 12:57:08.937834: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_73' with dtype float and shape [256]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_73}}]]
# 2023-06-10 12:57:08.937865: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_74' with dtype float and shape [?,4,4,256]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_74}}]]
# 2023-06-10 12:57:08.937896: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_75' with dtype float and shape [256]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_75}}]]
# 2023-06-10 12:57:08.937963: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_76' with dtype float and shape [1,?,256,1]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_76}}]]
# 2023-06-10 12:57:08.937997: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_84' with dtype float and shape [?,4,4,256]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_84}}]]
# 2023-06-10 12:57:08.938031: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_85' with dtype float and shape [?,4,4,256]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_85}}]]
# 2023-06-10 12:57:08.938102: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_86' with dtype float and shape [?,4,4,256]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_86}}]]
# 2023-06-10 12:57:08.938135: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_88' with dtype float and shape [?,4,4,256]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_88}}]]
# 2023-06-10 12:57:08.938166: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_89' with dtype float and shape [256]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_89}}]]
# 2023-06-10 12:57:08.938226: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_90' with dtype float and shape [?,4,4,256]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_90}}]]
# 2023-06-10 12:57:08.938291: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_91' with dtype float and shape [256]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_91}}]]
# 2023-06-10 12:57:08.938326: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_92' with dtype float and shape [1,?,256,1]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_92}}]]
# 2023-06-10 12:57:08.938386: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_100' with dtype float and shape [?,4,4,256]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_100}}]]
# 2023-06-10 12:57:08.938445: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_101' with dtype float and shape [?,4,4,256]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_101}}]]
# 2023-06-10 12:57:08.938557: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_103' with dtype float and shape [?,4,4,256]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_103}}]]
# 2023-06-10 12:57:08.938624: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_104' with dtype float and shape [256]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_104}}]]
# 2023-06-10 12:57:08.938666: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_105' with dtype float and shape [?,4,4,256]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_105}}]]
# 2023-06-10 12:57:08.938697: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_106' with dtype float and shape [256]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_106}}]]
# 2023-06-10 12:57:08.938728: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_107' with dtype float and shape [1,?,256,1]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_107}}]]
# 2023-06-10 12:57:08.938797: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_115' with dtype float and shape [?,4,4,256]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_115}}]]
# 2023-06-10 12:57:08.938865: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_116' with dtype float and shape [?,4,4,256]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_116}}]]
# 2023-06-10 12:57:08.938900: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_117' with dtype float and shape [?,7,7,128]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_117}}]]
# 2023-06-10 12:57:08.938955: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_119' with dtype float and shape [?,4,4,256]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_119}}]]
# 2023-06-10 12:57:08.938989: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_121' with dtype float and shape [?,4,4,256]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_121}}]]
# 2023-06-10 12:57:08.939026: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_122' with dtype float and shape [256]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_122}}]]
# 2023-06-10 12:57:08.939059: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_123' with dtype float and shape [?,4,4,256]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_123}}]]
# 2023-06-10 12:57:08.939116: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_124' with dtype float and shape [256]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_124}}]]
# 2023-06-10 12:57:08.939157: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_125' with dtype float and shape [1,?,256,1]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_125}}]]
# 2023-06-10 12:57:08.939189: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_133' with dtype float and shape [?,4,4,256]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_133}}]]
# 2023-06-10 12:57:08.939245: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_134' with dtype float and shape [?,7,7,128]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_134}}]]
# 2023-06-10 12:57:08.939278: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_136' with dtype float and shape [?,7,7,128]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_136}}]]
# 2023-06-10 12:57:08.939334: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_137' with dtype float and shape [128]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_137}}]]
# 2023-06-10 12:57:08.939380: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_138' with dtype float and shape [?,7,7,128]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_138}}]]
# 2023-06-10 12:57:08.939412: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_139' with dtype float and shape [128]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_139}}]]
# 2023-06-10 12:57:08.939444: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_140' with dtype float and shape [1,?,128,1]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_140}}]]
# 2023-06-10 12:57:08.939513: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_148' with dtype float and shape [?,7,7,128]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_148}}]]
# 2023-06-10 12:57:08.939571: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_149' with dtype float and shape [?,7,7,128]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_149}}]]
# 2023-06-10 12:57:08.939605: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_150' with dtype float and shape [?,7,7,128]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_150}}]]
# 2023-06-10 12:57:08.939638: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_152' with dtype float and shape [?,7,7,128]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_152}}]]
# 2023-06-10 12:57:08.939703: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_153' with dtype float and shape [128]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_153}}]]
# 2023-06-10 12:57:08.939736: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_154' with dtype float and shape [?,7,7,128]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_154}}]]
# 2023-06-10 12:57:08.939773: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_155' with dtype float and shape [128]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_155}}]]
# 2023-06-10 12:57:08.939805: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_156' with dtype float and shape [1,?,128,1]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_156}}]]
# 2023-06-10 12:57:08.939868: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_164' with dtype float and shape [?,7,7,128]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_164}}]]
# 2023-06-10 12:57:08.939901: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_165' with dtype float and shape [?,7,7,128]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_165}}]]
# 2023-06-10 12:57:08.939935: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_167' with dtype float and shape [?,7,7,128]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_167}}]]
# 2023-06-10 12:57:08.939997: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_168' with dtype float and shape [128]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_168}}]]
# 2023-06-10 12:57:08.940030: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_169' with dtype float and shape [?,7,7,128]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_169}}]]
# 2023-06-10 12:57:08.940062: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_170' with dtype float and shape [128]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_170}}]]
# 2023-06-10 12:57:08.940134: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_171' with dtype float and shape [1,?,128,1]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_171}}]]
# 2023-06-10 12:57:08.940169: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_179' with dtype float and shape [?,7,7,128]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_179}}]]
# 2023-06-10 12:57:08.940200: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_180' with dtype float and shape [?,7,7,128]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_180}}]]
# 2023-06-10 12:57:08.940256: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_181' with dtype float and shape [?,13,13,64]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_181}}]]
# 2023-06-10 12:57:08.940330: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_183' with dtype float and shape [?,7,7,128]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_183}}]]
# 2023-06-10 12:57:08.940364: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_185' with dtype float and shape [?,7,7,128]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_185}}]]
# 2023-06-10 12:57:08.940424: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_186' with dtype float and shape [128]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_186}}]]
# 2023-06-10 12:57:08.940498: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_187' with dtype float and shape [?,7,7,128]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_187}}]]
# 2023-06-10 12:57:08.940533: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_188' with dtype float and shape [128]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_188}}]]
# 2023-06-10 12:57:08.940606: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_189' with dtype float and shape [1,?,128,1]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_189}}]]
# 2023-06-10 12:57:08.940641: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_197' with dtype float and shape [?,7,7,128]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_197}}]]
# 2023-06-10 12:57:08.940711: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_198' with dtype float and shape [?,13,13,64]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_198}}]]
# 2023-06-10 12:57:08.940781: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_200' with dtype float and shape [?,13,13,64]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_200}}]]
# 2023-06-10 12:57:08.940816: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_201' with dtype float and shape [64]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_201}}]]
# 2023-06-10 12:57:08.940848: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_202' with dtype float and shape [?,13,13,64]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_202}}]]
# 2023-06-10 12:57:08.940918: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_203' with dtype float and shape [64]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_203}}]]
# 2023-06-10 12:57:08.940982: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_204' with dtype float and shape [1,?,64,1]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_204}}]]
# 2023-06-10 12:57:08.941015: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_212' with dtype float and shape [?,13,13,64]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_212}}]]
# 2023-06-10 12:57:08.941047: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_213' with dtype float and shape [?,13,13,64]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_213}}]]
# 2023-06-10 12:57:08.941103: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_214' with dtype float and shape [?,13,13,64]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_214}}]]
# 2023-06-10 12:57:08.941148: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_216' with dtype float and shape [?,13,13,64]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_216}}]]
# 2023-06-10 12:57:08.941180: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_217' with dtype float and shape [64]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_217}}]]
# 2023-06-10 12:57:08.941250: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_218' with dtype float and shape [?,13,13,64]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_218}}]]
# 2023-06-10 12:57:08.941301: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_219' with dtype float and shape [64]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_219}}]]
# 2023-06-10 12:57:08.941332: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_220' with dtype float and shape [1,?,64,1]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_220}}]]
# 2023-06-10 12:57:08.941389: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_228' with dtype float and shape [?,13,13,64]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_228}}]]
# 2023-06-10 12:57:08.941422: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_229' with dtype float and shape [?,13,13,64]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_229}}]]
# 2023-06-10 12:57:08.941512: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_231' with dtype float and shape [?,13,13,64]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_231}}]]
# 2023-06-10 12:57:08.941551: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_232' with dtype float and shape [64]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_232}}]]
# 2023-06-10 12:57:08.941597: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_233' with dtype float and shape [?,13,13,64]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_233}}]]
# 2023-06-10 12:57:08.941629: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_234' with dtype float and shape [64]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_234}}]]
# 2023-06-10 12:57:08.941705: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_235' with dtype float and shape [1,?,64,1]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_235}}]]
# 2023-06-10 12:57:08.941739: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_243' with dtype float and shape [?,13,13,64]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_243}}]]
# 2023-06-10 12:57:08.941774: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_244' with dtype float and shape [?,13,13,64]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_244}}]]
# 2023-06-10 12:57:08.941848: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_245' with dtype float and shape [?,13,13,64]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_245}}]]
# 2023-06-10 12:57:08.941882: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_247' with dtype float and shape [?,13,13,64]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_247}}]]
# 2023-06-10 12:57:08.941919: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_248' with dtype float and shape [64]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_248}}]]
# 2023-06-10 12:57:08.941955: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_249' with dtype float and shape [?,13,13,64]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_249}}]]
# 2023-06-10 12:57:08.942015: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_250' with dtype float and shape [64]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_250}}]]
# 2023-06-10 12:57:08.942091: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_251' with dtype float and shape [1,?,64,1]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_251}}]]
# 2023-06-10 12:57:08.942125: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_259' with dtype float and shape [?,13,13,64]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_259}}]]
# 2023-06-10 12:57:08.942160: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_262' with dtype float and shape [?,25,25,64]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_262}}]]
# 2023-06-10 12:57:08.942241: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_263' with dtype float and shape [64]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_263}}]]
# 2023-06-10 12:57:08.942275: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_264' with dtype float and shape [?,25,25,64]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_264}}]]
# 2023-06-10 12:57:08.942328: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_265' with dtype float and shape [64]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_265}}]]
# 2023-06-10 12:57:08.942363: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_266' with dtype float and shape [1,?,64,1]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_266}}]]
# 2023-06-10 12:57:08.942438: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_274' with dtype float and shape [?,25,25,64]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_274}}]]
# 2023-06-10 12:57:08.942490: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_275' with dtype float and shape [?,50,50,3]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_275}}]]

# %%
@tff.tf_computation(model_weights_type_h1)
def server_update_fn_h1(mean_client_weights):
  model = model_fn_h1()
  return server_update_h1(model, mean_client_weights)

# %%
federated_server_type_h1 = tff.FederatedType(model_weights_type_h1, tff.SERVER)
federated_dataset_type_h1 = tff.FederatedType(tf_dataset_type_h1, tff.CLIENTS)

# %%
@tff.federated_computation(federated_server_type_h1, federated_dataset_type_h1)
def next_fn_h1(server_weights, federated_dataset):
  # Broadcast the server weights to the clients.
  server_weights_at_client = tff.federated_broadcast(server_weights)

  # Each client computes their updated weights.
  client_weights = tff.federated_map(
      client_update_fn_h1, (federated_dataset, server_weights_at_client))
  
  # The server averages these updates.
  mean_client_weights = tff.federated_mean(client_weights)

  # The server updates its model.
  server_weights = tff.federated_map(server_update_fn_h1, mean_client_weights)


  return server_weights

# %%
federated_algorithm_h1 = tff.templates.IterativeProcess(
    initialize_fn=initialize_fn_h1,
    next_fn=next_fn_h1
)

# %% [markdown]
# ### H2

# %%
def model_fn_h2():
  model = build_h2_model()
  return tff.learning.models.from_keras_model(
      model,
      input_spec=state_train[0].element_spec,
      loss=tf.keras.losses.CategoricalCrossentropy(),
      metrics=[tf.keras.metrics.Accuracy()])

# %%
@tff.tf_computation
def server_init_h2():
  model = model_fn_h2()
  return model.trainable_variables

# %%
@tff.federated_computation
def initialize_fn_h2():
  return tff.federated_value(server_init_h2(), tff.SERVER)

# %%
@tf.function
def client_update_h2(model, dataset, server_weights, client_optimizer):
  """Performs training (using the server model weights) on the client's dataset."""
  # Initialize the client model with the current server weights.
  client_weights = model.trainable_variables
  # Assign the server weights to the client model.
  tf.nest.map_structure(lambda x, y: x.assign(y),
                        client_weights, server_weights)

  # Use the client_optimizer to update the local model.
  for batch in dataset:
    with tf.GradientTape() as tape:
      # Compute a forward pass on the batch of data
      outputs = model.forward_pass(batch)

    # Compute the corresponding gradient
    grads = tape.gradient(outputs.loss, client_weights)
    grads_and_vars = zip(grads, client_weights)

    # Apply the gradient using a client optimizer.
    client_optimizer.apply_gradients(grads_and_vars)

  return client_weights

# %%
@tf.function
def server_update_h2(model, mean_client_weights):
  """Updates the server model weights as the average of the client model weights."""
  model_weights = model.trainable_variables
  # Assign the mean client weights to the server model.
  tf.nest.map_structure(lambda x, y: x.assign(y),
                        model_weights, mean_client_weights)
  return model_weights

# %%
h2_fed = model_fn_h2()
tf_dataset_type_h2 = tff.SequenceType(h2_fed.input_spec)

# %%
str(tf_dataset_type_h2)
# Out:
# '<float32[?,50,50,3],float32[?,10]>*'

# %%
model_weights_type_h2 = h2_fed.trainable_variables
# Assuming model_weights_type is a list of trainable variables
model_weights_type_h2 = [v for v in model_weights_type_h2]

model_weights_type_h2 = tff.to_type([tf.TensorSpec.from_tensor(v.value()) for v in model_weights_type_h2])

# %%
@tff.tf_computation(tf_dataset_type_h2, model_weights_type_h2)
def client_update_fn_h2(tf_dataset, server_weights):
  model = model_fn_h2()
  client_optimizer = tf.keras.optimizers.SGD(learning_rate=0.01)
  return client_update_h2(model, tf_dataset, server_weights, client_optimizer)
# Out:
# 2023-06-10 12:57:16.285322: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_7' with dtype float and shape [?,1,1,512]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_7}}]]
# 2023-06-10 12:57:16.285719: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_8' with dtype int32 and shape [2]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_8}}]]
# 2023-06-10 12:57:16.285757: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_9' with dtype float and shape [?,2,2,512]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_9}}]]
# 2023-06-10 12:57:16.285792: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_10' with dtype float and shape [?,2,2,512]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_10}}]]
# 2023-06-10 12:57:16.285824: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_11' with dtype float and shape [512]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_11}}]]
# 2023-06-10 12:57:16.285856: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_12' with dtype float and shape [?,2,2,512]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_12}}]]
# 2023-06-10 12:57:16.285891: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_13' with dtype float and shape [512]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_13}}]]
# 2023-06-10 12:57:16.285922: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_14' with dtype float and shape [1,?,512,1]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_14}}]]
# 2023-06-10 12:57:16.285953: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_22' with dtype float and shape [?,2,2,512]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_22}}]]
# 2023-06-10 12:57:16.285985: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_23' with dtype float and shape [?,2,2,512]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_23}}]]
# 2023-06-10 12:57:16.286016: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_24' with dtype float and shape [?,2,2,512]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_24}}]]
# 2023-06-10 12:57:16.286046: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_25' with dtype float and shape [?,2,2,512]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_25}}]]
# 2023-06-10 12:57:16.286078: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_27' with dtype float and shape [?,2,2,512]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_27}}]]
# 2023-06-10 12:57:16.286108: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_28' with dtype float and shape [512]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_28}}]]
# 2023-06-10 12:57:16.286137: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_29' with dtype float and shape [?,2,2,512]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_29}}]]
# 2023-06-10 12:57:16.286167: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_30' with dtype float and shape [512]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_30}}]]
# 2023-06-10 12:57:16.286198: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_31' with dtype float and shape [1,?,512,1]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_31}}]]
# 2023-06-10 12:57:16.286229: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_39' with dtype float and shape [?,2,2,512]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_39}}]]
# 2023-06-10 12:57:16.286260: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_40' with dtype float and shape [?,2,2,512]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_40}}]]
# 2023-06-10 12:57:16.286292: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_42' with dtype float and shape [?,2,2,512]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_42}}]]
# 2023-06-10 12:57:16.286323: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_43' with dtype float and shape [512]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_43}}]]
# 2023-06-10 12:57:16.286354: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_44' with dtype float and shape [?,2,2,512]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_44}}]]
# 2023-06-10 12:57:16.286386: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_45' with dtype float and shape [512]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_45}}]]
# 2023-06-10 12:57:16.286447: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_46' with dtype float and shape [1,?,512,1]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_46}}]]
# 2023-06-10 12:57:16.286505: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_54' with dtype float and shape [?,2,2,512]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_54}}]]
# 2023-06-10 12:57:16.286564: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_55' with dtype float and shape [?,2,2,512]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_55}}]]
# 2023-06-10 12:57:16.286623: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_56' with dtype float and shape [?,4,4,256]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_56}}]]
# 2023-06-10 12:57:16.286688: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_58' with dtype float and shape [?,2,2,512]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_58}}]]
# 2023-06-10 12:57:16.286744: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_60' with dtype float and shape [?,2,2,512]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_60}}]]
# 2023-06-10 12:57:16.286802: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_61' with dtype float and shape [512]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_61}}]]
# 2023-06-10 12:57:16.286860: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_62' with dtype float and shape [?,2,2,512]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_62}}]]
# 2023-06-10 12:57:16.286925: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_63' with dtype float and shape [512]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_63}}]]
# 2023-06-10 12:57:16.286986: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_64' with dtype float and shape [1,?,512,1]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_64}}]]
# 2023-06-10 12:57:16.287043: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_72' with dtype float and shape [?,2,2,512]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_72}}]]
# 2023-06-10 12:57:16.287100: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_73' with dtype float and shape [?,4,4,256]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_73}}]]
# 2023-06-10 12:57:16.287157: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_75' with dtype float and shape [?,4,4,256]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_75}}]]
# 2023-06-10 12:57:16.287215: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_76' with dtype float and shape [256]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_76}}]]
# 2023-06-10 12:57:16.287273: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_77' with dtype float and shape [?,4,4,256]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_77}}]]
# 2023-06-10 12:57:16.287330: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_78' with dtype float and shape [256]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_78}}]]
# 2023-06-10 12:57:16.287388: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_79' with dtype float and shape [1,?,256,1]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_79}}]]
# 2023-06-10 12:57:16.287446: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_87' with dtype float and shape [?,4,4,256]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_87}}]]
# 2023-06-10 12:57:16.287504: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_88' with dtype float and shape [?,4,4,256]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_88}}]]
# 2023-06-10 12:57:16.287562: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_89' with dtype float and shape [?,4,4,256]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_89}}]]
# 2023-06-10 12:57:16.287619: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_91' with dtype float and shape [?,4,4,256]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_91}}]]
# 2023-06-10 12:57:16.287683: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_92' with dtype float and shape [256]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_92}}]]
# 2023-06-10 12:57:16.287742: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_93' with dtype float and shape [?,4,4,256]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_93}}]]
# 2023-06-10 12:57:16.287799: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_94' with dtype float and shape [256]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_94}}]]
# 2023-06-10 12:57:16.287856: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_95' with dtype float and shape [1,?,256,1]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_95}}]]
# 2023-06-10 12:57:16.287913: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_103' with dtype float and shape [?,4,4,256]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_103}}]]
# 2023-06-10 12:57:16.287984: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_104' with dtype float and shape [?,4,4,256]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_104}}]]
# 2023-06-10 12:57:16.288017: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_106' with dtype float and shape [?,4,4,256]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_106}}]]
# 2023-06-10 12:57:16.288048: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_107' with dtype float and shape [256]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_107}}]]
# 2023-06-10 12:57:16.288079: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_108' with dtype float and shape [?,4,4,256]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_108}}]]
# 2023-06-10 12:57:16.288143: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_109' with dtype float and shape [256]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_109}}]]
# 2023-06-10 12:57:16.288176: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_110' with dtype float and shape [1,?,256,1]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_110}}]]
# 2023-06-10 12:57:16.288207: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_118' with dtype float and shape [?,4,4,256]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_118}}]]
# 2023-06-10 12:57:16.288241: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_119' with dtype float and shape [?,4,4,256]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_119}}]]
# 2023-06-10 12:57:16.288306: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_120' with dtype float and shape [?,7,7,128]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_120}}]]
# 2023-06-10 12:57:16.288338: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_122' with dtype float and shape [?,4,4,256]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_122}}]]
# 2023-06-10 12:57:16.288369: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_124' with dtype float and shape [?,4,4,256]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_124}}]]
# 2023-06-10 12:57:16.288400: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_125' with dtype float and shape [256]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_125}}]]
# 2023-06-10 12:57:16.288464: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_126' with dtype float and shape [?,4,4,256]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_126}}]]
# 2023-06-10 12:57:16.288497: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_127' with dtype float and shape [256]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_127}}]]
# 2023-06-10 12:57:16.288528: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_128' with dtype float and shape [1,?,256,1]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_128}}]]
# 2023-06-10 12:57:16.288592: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_136' with dtype float and shape [?,4,4,256]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_136}}]]
# 2023-06-10 12:57:16.288634: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_137' with dtype float and shape [?,7,7,128]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_137}}]]
# 2023-06-10 12:57:16.288724: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_139' with dtype float and shape [?,7,7,128]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_139}}]]
# 2023-06-10 12:57:16.288781: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_140' with dtype float and shape [128]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_140}}]]
# 2023-06-10 12:57:16.288813: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_141' with dtype float and shape [?,7,7,128]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_141}}]]
# 2023-06-10 12:57:16.288845: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_142' with dtype float and shape [128]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_142}}]]
# 2023-06-10 12:57:16.288917: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_143' with dtype float and shape [1,?,128,1]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_143}}]]
# 2023-06-10 12:57:16.288949: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_151' with dtype float and shape [?,7,7,128]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_151}}]]
# 2023-06-10 12:57:16.288980: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_152' with dtype float and shape [?,7,7,128]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_152}}]]
# 2023-06-10 12:57:16.289016: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_153' with dtype float and shape [?,7,7,128]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_153}}]]
# 2023-06-10 12:57:16.289075: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_155' with dtype float and shape [?,7,7,128]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_155}}]]
# 2023-06-10 12:57:16.289107: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_156' with dtype float and shape [128]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_156}}]]
# 2023-06-10 12:57:16.289138: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_157' with dtype float and shape [?,7,7,128]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_157}}]]
# 2023-06-10 12:57:16.289169: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_158' with dtype float and shape [128]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_158}}]]
# 2023-06-10 12:57:16.289238: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_159' with dtype float and shape [1,?,128,1]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_159}}]]
# 2023-06-10 12:57:16.289271: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_167' with dtype float and shape [?,7,7,128]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_167}}]]
# 2023-06-10 12:57:16.289302: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_168' with dtype float and shape [?,7,7,128]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_168}}]]
# 2023-06-10 12:57:16.289368: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_170' with dtype float and shape [?,7,7,128]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_170}}]]
# 2023-06-10 12:57:16.289400: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_171' with dtype float and shape [128]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_171}}]]
# 2023-06-10 12:57:16.289432: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_172' with dtype float and shape [?,7,7,128]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_172}}]]
# 2023-06-10 12:57:16.289466: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_173' with dtype float and shape [128]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_173}}]]
# 2023-06-10 12:57:16.289525: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_174' with dtype float and shape [1,?,128,1]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_174}}]]
# 2023-06-10 12:57:16.289558: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_182' with dtype float and shape [?,7,7,128]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_182}}]]
# 2023-06-10 12:57:16.289588: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_183' with dtype float and shape [?,7,7,128]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_183}}]]
# 2023-06-10 12:57:16.289663: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_184' with dtype float and shape [?,13,13,64]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_184}}]]
# 2023-06-10 12:57:16.289698: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_186' with dtype float and shape [?,7,7,128]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_186}}]]
# 2023-06-10 12:57:16.289729: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_188' with dtype float and shape [?,7,7,128]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_188}}]]
# 2023-06-10 12:57:16.289801: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_189' with dtype float and shape [128]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_189}}]]
# 2023-06-10 12:57:16.289834: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_190' with dtype float and shape [?,7,7,128]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_190}}]]
# 2023-06-10 12:57:16.289865: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_191' with dtype float and shape [128]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_191}}]]
# 2023-06-10 12:57:16.289895: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_192' with dtype float and shape [1,?,128,1]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_192}}]]
# 2023-06-10 12:57:16.289951: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_200' with dtype float and shape [?,7,7,128]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_200}}]]
# 2023-06-10 12:57:16.290021: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_201' with dtype float and shape [?,13,13,64]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_201}}]]
# 2023-06-10 12:57:16.290053: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_203' with dtype float and shape [?,13,13,64]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_203}}]]
# 2023-06-10 12:57:16.290085: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_204' with dtype float and shape [64]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_204}}]]
# 2023-06-10 12:57:16.290149: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_205' with dtype float and shape [?,13,13,64]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_205}}]]
# 2023-06-10 12:57:16.290181: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_206' with dtype float and shape [64]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_206}}]]
# 2023-06-10 12:57:16.290213: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_207' with dtype float and shape [1,?,64,1]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_207}}]]
# 2023-06-10 12:57:16.290268: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_215' with dtype float and shape [?,13,13,64]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_215}}]]
# 2023-06-10 12:57:16.290328: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_216' with dtype float and shape [?,13,13,64]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_216}}]]
# 2023-06-10 12:57:16.290362: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_217' with dtype float and shape [?,13,13,64]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_217}}]]
# 2023-06-10 12:57:16.290393: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_219' with dtype float and shape [?,13,13,64]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_219}}]]
# 2023-06-10 12:57:16.290441: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_220' with dtype float and shape [64]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_220}}]]
# 2023-06-10 12:57:16.290494: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_221' with dtype float and shape [?,13,13,64]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_221}}]]
# 2023-06-10 12:57:16.290526: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_222' with dtype float and shape [64]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_222}}]]
# 2023-06-10 12:57:16.290557: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_223' with dtype float and shape [1,?,64,1]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_223}}]]
# 2023-06-10 12:57:16.290634: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_231' with dtype float and shape [?,13,13,64]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_231}}]]
# 2023-06-10 12:57:16.290679: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_232' with dtype float and shape [?,13,13,64]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_232}}]]
# 2023-06-10 12:57:16.290710: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_234' with dtype float and shape [?,13,13,64]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_234}}]]
# 2023-06-10 12:57:16.290780: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_235' with dtype float and shape [64]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_235}}]]
# 2023-06-10 12:57:16.290813: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_236' with dtype float and shape [?,13,13,64]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_236}}]]
# 2023-06-10 12:57:16.290843: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_237' with dtype float and shape [64]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_237}}]]
# 2023-06-10 12:57:16.290874: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_238' with dtype float and shape [1,?,64,1]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_238}}]]
# 2023-06-10 12:57:16.290942: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_246' with dtype float and shape [?,13,13,64]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_246}}]]
# 2023-06-10 12:57:16.290976: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_247' with dtype float and shape [?,13,13,64]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_247}}]]
# 2023-06-10 12:57:16.291007: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_248' with dtype float and shape [?,13,13,64]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_248}}]]
# 2023-06-10 12:57:16.291038: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_250' with dtype float and shape [?,13,13,64]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_250}}]]
# 2023-06-10 12:57:16.291068: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_251' with dtype float and shape [64]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_251}}]]
# 2023-06-10 12:57:16.291099: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_252' with dtype float and shape [?,13,13,64]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_252}}]]
# 2023-06-10 12:57:16.291131: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_253' with dtype float and shape [64]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_253}}]]
# 2023-06-10 12:57:16.291201: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_254' with dtype float and shape [1,?,64,1]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_254}}]]
# 2023-06-10 12:57:16.291235: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_262' with dtype float and shape [?,13,13,64]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_262}}]]
# 2023-06-10 12:57:16.291266: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_265' with dtype float and shape [?,25,25,64]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_265}}]]
# 2023-06-10 12:57:16.291338: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_266' with dtype float and shape [64]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_266}}]]
# 2023-06-10 12:57:16.291370: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_267' with dtype float and shape [?,25,25,64]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_267}}]]
# 2023-06-10 12:57:16.291401: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_268' with dtype float and shape [64]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_268}}]]
# 2023-06-10 12:57:16.291431: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_269' with dtype float and shape [1,?,64,1]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_269}}]]
# 2023-06-10 12:57:16.291463: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_277' with dtype float and shape [?,25,25,64]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_277}}]]
# 2023-06-10 12:57:16.291519: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_278' with dtype float and shape [?,50,50,3]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_278}}]]

# %%
@tff.tf_computation(model_weights_type_h2)
def server_update_fn_h2(mean_client_weights):
  model = model_fn_h2()
  return server_update_h2(model, mean_client_weights)

# %%
federated_server_type_h2 = tff.FederatedType(model_weights_type_h2, tff.SERVER)
federated_dataset_type_h2 = tff.FederatedType(tf_dataset_type_h2, tff.CLIENTS)

# %%
@tff.federated_computation(federated_server_type_h2, federated_dataset_type_h2)
def next_fn_h2(server_weights, federated_dataset):
  # Broadcast the server weights to the clients.
  server_weights_at_client = tff.federated_broadcast(server_weights)

  # Each client computes their updated weights.
  client_weights = tff.federated_map(
      client_update_fn_h2, (federated_dataset, server_weights_at_client))
  
  # The server averages these updates.
  mean_client_weights = tff.federated_mean(client_weights)

  # The server updates its model.
  server_weights = tff.federated_map(server_update_fn_h2, mean_client_weights)

  return server_weights

# %%
federated_algorithm_h2 = tff.templates.IterativeProcess(
    initialize_fn=initialize_fn_h2,
    next_fn=next_fn_h2
)

# %% [markdown]
# ### H3

# %%
def model_fn_h3():
  model = build_h3_model()
  return tff.learning.models.from_keras_model(
      model,
      input_spec=regress_train[0].element_spec,
      loss=tf.keras.losses.MeanSquaredError(),
      metrics=[tf.keras.metrics.MeanSquaredError()])

# %%
@tff.tf_computation
def server_init_h3():
  model = model_fn_h3()
  return model.trainable_variables

# %%
@tff.federated_computation
def initialize_fn_h3():
  return tff.federated_value(server_init_h3(), tff.SERVER)

# %%
@tf.function
def client_update_h3(model, dataset, server_weights, client_optimizer):
  """Performs training (using the server model weights) on the client's dataset."""
  # Initialize the client model with the current server weights.
  client_weights = model.trainable_variables
  # Assign the server weights to the client model.
  tf.nest.map_structure(lambda x, y: x.assign(y),
                        client_weights, server_weights)

  # Use the client_optimizer to update the local model.
  for batch in dataset:
    with tf.GradientTape() as tape:
      # Compute a forward pass on the batch of data
      outputs = model.forward_pass(batch)

    # Compute the corresponding gradient
    grads = tape.gradient(outputs.loss, client_weights)
    grads_and_vars = zip(grads, client_weights)

    # Apply the gradient using a client optimizer.
    client_optimizer.apply_gradients(grads_and_vars)

  return client_weights

# %%
@tf.function
def server_update_h3(model, mean_client_weights):
  """Updates the server model weights as the average of the client model weights."""
  model_weights = model.trainable_variables
  # Assign the mean client weights to the server model.
  tf.nest.map_structure(lambda x, y: x.assign(y),
                        model_weights, mean_client_weights)
  return model_weights

# %%
h3_fed = model_fn_h3()
tf_dataset_type_h3 = tff.SequenceType(h3_fed.input_spec)

# %%
str(tf_dataset_type_h3)
# Out:
# '<float32[?,50,50,3],float64[?,1]>*'

# %%
model_weights_type_h3 = h3_fed.trainable_variables
# Assuming model_weights_type is a list of trainable variables
model_weights_type_h3 = [v for v in model_weights_type_h3]

model_weights_type_h3 = tff.to_type([tf.TensorSpec.from_tensor(v.value()) for v in model_weights_type_h3])

# %%
@tff.tf_computation(tf_dataset_type_h3, model_weights_type_h3)
def client_update_fn_h3(tf_dataset, server_weights):
  model = model_fn_h3()
  client_optimizer = tf.keras.optimizers.SGD(learning_rate=0.01)
  return client_update_h3(model, tf_dataset, server_weights, client_optimizer)
# Out:
# 2023-06-10 12:57:24.632060: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_12' with dtype float and shape [?,1,1,512]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_12}}]]
# 2023-06-10 12:57:24.632181: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_13' with dtype int32 and shape [2]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_13}}]]
# 2023-06-10 12:57:24.632224: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_14' with dtype float and shape [?,2,2,512]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_14}}]]
# 2023-06-10 12:57:24.632262: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_15' with dtype float and shape [?,2,2,512]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_15}}]]
# 2023-06-10 12:57:24.632298: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_16' with dtype float and shape [512]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_16}}]]
# 2023-06-10 12:57:24.632334: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_17' with dtype float and shape [?,2,2,512]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_17}}]]
# 2023-06-10 12:57:24.632370: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_18' with dtype float and shape [512]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_18}}]]
# 2023-06-10 12:57:24.632420: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_19' with dtype float and shape [1,?,512,1]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_19}}]]
# 2023-06-10 12:57:24.632475: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_27' with dtype float and shape [?,2,2,512]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_27}}]]
# 2023-06-10 12:57:24.632527: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_28' with dtype float and shape [?,2,2,512]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_28}}]]
# 2023-06-10 12:57:24.632583: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_29' with dtype float and shape [?,2,2,512]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_29}}]]
# 2023-06-10 12:57:24.632639: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_30' with dtype float and shape [?,2,2,512]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_30}}]]
# 2023-06-10 12:57:24.632721: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_32' with dtype float and shape [?,2,2,512]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_32}}]]
# 2023-06-10 12:57:24.632782: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_33' with dtype float and shape [512]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_33}}]]
# 2023-06-10 12:57:24.632875: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_34' with dtype float and shape [?,2,2,512]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_34}}]]
# 2023-06-10 12:57:24.632964: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_35' with dtype float and shape [512]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_35}}]]
# 2023-06-10 12:57:24.633054: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_36' with dtype float and shape [1,?,512,1]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_36}}]]
# 2023-06-10 12:57:24.633117: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_44' with dtype float and shape [?,2,2,512]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_44}}]]
# 2023-06-10 12:57:24.633212: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_45' with dtype float and shape [?,2,2,512]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_45}}]]
# 2023-06-10 12:57:24.633305: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_47' with dtype float and shape [?,2,2,512]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_47}}]]
# 2023-06-10 12:57:24.633416: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_48' with dtype float and shape [512]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_48}}]]
# 2023-06-10 12:57:24.633515: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_49' with dtype float and shape [?,2,2,512]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_49}}]]
# 2023-06-10 12:57:24.633613: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_50' with dtype float and shape [512]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_50}}]]
# 2023-06-10 12:57:24.633746: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_51' with dtype float and shape [1,?,512,1]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_51}}]]
# 2023-06-10 12:57:24.633871: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_59' with dtype float and shape [?,2,2,512]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_59}}]]
# 2023-06-10 12:57:24.633964: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_60' with dtype float and shape [?,2,2,512]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_60}}]]
# 2023-06-10 12:57:24.634056: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_61' with dtype float and shape [?,4,4,256]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_61}}]]
# 2023-06-10 12:57:24.634159: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_63' with dtype float and shape [?,2,2,512]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_63}}]]
# 2023-06-10 12:57:24.634249: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_65' with dtype float and shape [?,2,2,512]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_65}}]]
# 2023-06-10 12:57:24.634338: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_66' with dtype float and shape [512]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_66}}]]
# 2023-06-10 12:57:24.634426: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_67' with dtype float and shape [?,2,2,512]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_67}}]]
# 2023-06-10 12:57:24.634513: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_68' with dtype float and shape [512]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_68}}]]
# 2023-06-10 12:57:24.634602: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_69' with dtype float and shape [1,?,512,1]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_69}}]]
# 2023-06-10 12:57:24.634723: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_77' with dtype float and shape [?,2,2,512]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_77}}]]
# 2023-06-10 12:57:24.634812: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_78' with dtype float and shape [?,4,4,256]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_78}}]]
# 2023-06-10 12:57:24.634899: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_80' with dtype float and shape [?,4,4,256]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_80}}]]
# 2023-06-10 12:57:24.634987: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_81' with dtype float and shape [256]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_81}}]]
# 2023-06-10 12:57:24.635075: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_82' with dtype float and shape [?,4,4,256]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_82}}]]
# 2023-06-10 12:57:24.635168: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_83' with dtype float and shape [256]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_83}}]]
# 2023-06-10 12:57:24.635292: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_84' with dtype float and shape [1,?,256,1]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_84}}]]
# 2023-06-10 12:57:24.635392: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_92' with dtype float and shape [?,4,4,256]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_92}}]]
# 2023-06-10 12:57:24.635520: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_93' with dtype float and shape [?,4,4,256]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_93}}]]
# 2023-06-10 12:57:24.635624: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_94' with dtype float and shape [?,4,4,256]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_94}}]]
# 2023-06-10 12:57:24.635720: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_96' with dtype float and shape [?,4,4,256]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_96}}]]
# 2023-06-10 12:57:24.635821: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_97' with dtype float and shape [256]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_97}}]]
# 2023-06-10 12:57:24.635917: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_98' with dtype float and shape [?,4,4,256]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_98}}]]
# 2023-06-10 12:57:24.636013: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_99' with dtype float and shape [256]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_99}}]]
# 2023-06-10 12:57:24.636113: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_100' with dtype float and shape [1,?,256,1]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_100}}]]
# 2023-06-10 12:57:24.636217: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_108' with dtype float and shape [?,4,4,256]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_108}}]]
# 2023-06-10 12:57:24.636314: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_109' with dtype float and shape [?,4,4,256]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_109}}]]
# 2023-06-10 12:57:24.636403: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_111' with dtype float and shape [?,4,4,256]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_111}}]]
# 2023-06-10 12:57:24.636493: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_112' with dtype float and shape [256]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_112}}]]
# 2023-06-10 12:57:24.636591: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_113' with dtype float and shape [?,4,4,256]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_113}}]]
# 2023-06-10 12:57:24.636672: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_114' with dtype float and shape [256]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_114}}]]
# 2023-06-10 12:57:24.636753: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_115' with dtype float and shape [1,?,256,1]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_115}}]]
# 2023-06-10 12:57:24.636833: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_123' with dtype float and shape [?,4,4,256]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_123}}]]
# 2023-06-10 12:57:24.636912: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_124' with dtype float and shape [?,4,4,256]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_124}}]]
# 2023-06-10 12:57:24.636991: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_125' with dtype float and shape [?,7,7,128]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_125}}]]
# 2023-06-10 12:57:24.637072: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_127' with dtype float and shape [?,4,4,256]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_127}}]]
# 2023-06-10 12:57:24.637151: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_129' with dtype float and shape [?,4,4,256]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_129}}]]
# 2023-06-10 12:57:24.637229: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_130' with dtype float and shape [256]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_130}}]]
# 2023-06-10 12:57:24.637307: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_131' with dtype float and shape [?,4,4,256]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_131}}]]
# 2023-06-10 12:57:24.637385: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_132' with dtype float and shape [256]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_132}}]]
# 2023-06-10 12:57:24.637465: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_133' with dtype float and shape [1,?,256,1]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_133}}]]
# 2023-06-10 12:57:24.637567: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_141' with dtype float and shape [?,4,4,256]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_141}}]]
# 2023-06-10 12:57:24.637654: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_142' with dtype float and shape [?,7,7,128]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_142}}]]
# 2023-06-10 12:57:24.637742: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_144' with dtype float and shape [?,7,7,128]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_144}}]]
# 2023-06-10 12:57:24.637828: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_145' with dtype float and shape [128]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_145}}]]
# 2023-06-10 12:57:24.637913: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_146' with dtype float and shape [?,7,7,128]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_146}}]]
# 2023-06-10 12:57:24.637998: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_147' with dtype float and shape [128]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_147}}]]
# 2023-06-10 12:57:24.638082: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_148' with dtype float and shape [1,?,128,1]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_148}}]]
# 2023-06-10 12:57:24.638170: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_156' with dtype float and shape [?,7,7,128]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_156}}]]
# 2023-06-10 12:57:24.638257: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_157' with dtype float and shape [?,7,7,128]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_157}}]]
# 2023-06-10 12:57:24.638342: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_158' with dtype float and shape [?,7,7,128]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_158}}]]
# 2023-06-10 12:57:24.638429: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_160' with dtype float and shape [?,7,7,128]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_160}}]]
# 2023-06-10 12:57:24.638514: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_161' with dtype float and shape [128]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_161}}]]
# 2023-06-10 12:57:24.638604: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_162' with dtype float and shape [?,7,7,128]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_162}}]]
# 2023-06-10 12:57:24.638687: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_163' with dtype float and shape [128]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_163}}]]
# 2023-06-10 12:57:24.638771: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_164' with dtype float and shape [1,?,128,1]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_164}}]]
# 2023-06-10 12:57:24.638856: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_172' with dtype float and shape [?,7,7,128]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_172}}]]
# 2023-06-10 12:57:24.638941: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_173' with dtype float and shape [?,7,7,128]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_173}}]]
# 2023-06-10 12:57:24.639027: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_175' with dtype float and shape [?,7,7,128]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_175}}]]
# 2023-06-10 12:57:24.639112: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_176' with dtype float and shape [128]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_176}}]]
# 2023-06-10 12:57:24.639198: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_177' with dtype float and shape [?,7,7,128]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_177}}]]
# 2023-06-10 12:57:24.639404: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_178' with dtype float and shape [128]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_178}}]]
# 2023-06-10 12:57:24.639534: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_179' with dtype float and shape [1,?,128,1]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_179}}]]
# 2023-06-10 12:57:24.639643: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_187' with dtype float and shape [?,7,7,128]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_187}}]]
# 2023-06-10 12:57:24.639739: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_188' with dtype float and shape [?,7,7,128]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_188}}]]
# 2023-06-10 12:57:24.639836: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_189' with dtype float and shape [?,13,13,64]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_189}}]]
# 2023-06-10 12:57:24.639928: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_191' with dtype float and shape [?,7,7,128]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_191}}]]
# 2023-06-10 12:57:24.640020: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_193' with dtype float and shape [?,7,7,128]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_193}}]]
# 2023-06-10 12:57:24.640112: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_194' with dtype float and shape [128]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_194}}]]
# 2023-06-10 12:57:24.640203: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_195' with dtype float and shape [?,7,7,128]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_195}}]]
# 2023-06-10 12:57:24.640294: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_196' with dtype float and shape [128]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_196}}]]
# 2023-06-10 12:57:24.640385: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_197' with dtype float and shape [1,?,128,1]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_197}}]]
# 2023-06-10 12:57:24.640477: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_205' with dtype float and shape [?,7,7,128]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_205}}]]
# 2023-06-10 12:57:24.640582: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_206' with dtype float and shape [?,13,13,64]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_206}}]]
# 2023-06-10 12:57:24.640673: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_208' with dtype float and shape [?,13,13,64]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_208}}]]
# 2023-06-10 12:57:24.640765: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_209' with dtype float and shape [64]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_209}}]]
# 2023-06-10 12:57:24.640852: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_210' with dtype float and shape [?,13,13,64]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_210}}]]
# 2023-06-10 12:57:24.640943: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_211' with dtype float and shape [64]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_211}}]]
# 2023-06-10 12:57:24.641034: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_212' with dtype float and shape [1,?,64,1]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_212}}]]
# 2023-06-10 12:57:24.641124: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_220' with dtype float and shape [?,13,13,64]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_220}}]]
# 2023-06-10 12:57:24.641214: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_221' with dtype float and shape [?,13,13,64]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_221}}]]
# 2023-06-10 12:57:24.641303: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_222' with dtype float and shape [?,13,13,64]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_222}}]]
# 2023-06-10 12:57:24.641391: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_224' with dtype float and shape [?,13,13,64]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_224}}]]
# 2023-06-10 12:57:24.641479: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_225' with dtype float and shape [64]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_225}}]]
# 2023-06-10 12:57:24.641580: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_226' with dtype float and shape [?,13,13,64]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_226}}]]
# 2023-06-10 12:57:24.641669: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_227' with dtype float and shape [64]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_227}}]]
# 2023-06-10 12:57:24.641758: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_228' with dtype float and shape [1,?,64,1]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_228}}]]
# 2023-06-10 12:57:24.641848: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_236' with dtype float and shape [?,13,13,64]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_236}}]]
# 2023-06-10 12:57:24.641939: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_237' with dtype float and shape [?,13,13,64]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_237}}]]
# 2023-06-10 12:57:24.642027: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_239' with dtype float and shape [?,13,13,64]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_239}}]]
# 2023-06-10 12:57:24.642117: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_240' with dtype float and shape [64]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_240}}]]
# 2023-06-10 12:57:24.642204: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_241' with dtype float and shape [?,13,13,64]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_241}}]]
# 2023-06-10 12:57:24.642291: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_242' with dtype float and shape [64]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_242}}]]
# 2023-06-10 12:57:24.642380: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_243' with dtype float and shape [1,?,64,1]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_243}}]]
# 2023-06-10 12:57:24.642468: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_251' with dtype float and shape [?,13,13,64]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_251}}]]
# 2023-06-10 12:57:24.642570: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_252' with dtype float and shape [?,13,13,64]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_252}}]]
# 2023-06-10 12:57:24.642660: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_253' with dtype float and shape [?,13,13,64]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_253}}]]
# 2023-06-10 12:57:24.642747: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_255' with dtype float and shape [?,13,13,64]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_255}}]]
# 2023-06-10 12:57:24.642835: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_256' with dtype float and shape [64]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_256}}]]
# 2023-06-10 12:57:24.642922: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_257' with dtype float and shape [?,13,13,64]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_257}}]]
# 2023-06-10 12:57:24.642982: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_258' with dtype float and shape [64]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_258}}]]
# 2023-06-10 12:57:24.643073: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_259' with dtype float and shape [1,?,64,1]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_259}}]]
# 2023-06-10 12:57:24.643164: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_267' with dtype float and shape [?,13,13,64]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_267}}]]
# 2023-06-10 12:57:24.643254: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_270' with dtype float and shape [?,25,25,64]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_270}}]]
# 2023-06-10 12:57:24.643342: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_271' with dtype float and shape [64]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_271}}]]
# 2023-06-10 12:57:24.643445: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_272' with dtype float and shape [?,25,25,64]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_272}}]]
# 2023-06-10 12:57:24.643547: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_273' with dtype float and shape [64]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_273}}]]
# 2023-06-10 12:57:24.643635: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_274' with dtype float and shape [1,?,64,1]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_274}}]]
# 2023-06-10 12:57:24.643726: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_282' with dtype float and shape [?,25,25,64]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_282}}]]
# 2023-06-10 12:57:24.643815: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_283' with dtype float and shape [?,50,50,3]
# 	 [[{{node gradients/StatefulPartitionedCall_grad/StatefulPartitionedCall_283}}]]

# %%
@tff.tf_computation(model_weights_type_h3)
def server_update_fn_h3(mean_client_weights):
  model = model_fn_h3()
  return server_update_h3(model, mean_client_weights)

# %%
federated_server_type_h3 = tff.FederatedType(model_weights_type_h3, tff.SERVER)
federated_dataset_type_h3 = tff.FederatedType(tf_dataset_type_h3, tff.CLIENTS)

# %%
@tff.federated_computation(federated_server_type_h3, federated_dataset_type_h3)
def next_fn_h3(server_weights, federated_dataset):
  # Broadcast the server weights to the clients.
  server_weights_at_client = tff.federated_broadcast(server_weights)

  # Each client computes their updated weights.
  client_weights = tff.federated_map(
      client_update_fn_h3, (federated_dataset, server_weights_at_client))
  
  # The server averages these updates.
  mean_client_weights = tff.federated_mean(client_weights)

  # The server updates its model.
  server_weights = tff.federated_map(server_update_fn_h3, mean_client_weights)

  return server_weights

# %%
federated_algorithm_h3 = tff.templates.IterativeProcess(
    initialize_fn=initialize_fn_h3,
    next_fn=next_fn_h3
)

# %% [markdown]
# ## Model Evaluation

# %% [markdown]
# ### Creating test sets

# %%
def create_test_set(federated_test_set, num_classes):
  # Create a list to store client datasets
  client_datasets = []

  # Iterate over client IDs and create datasets
  for client_id in federated_test_set.client_ids:
      client_dataset = federated_test_set.create_tf_dataset_for_client(client_id)
      client_datasets.append(client_dataset)

  # Combine the client datasets into a centralized dataset
  test_set = tf.data.experimental.sample_from_datasets(client_datasets)
  test_set = preprocess(test_set, num_classes)
  return test_set

# %%
phase_test_central = create_test_set(phase_test_federated_data, PHASE_CLASSES)
state_test_central = create_test_set(state_test_federated_data, STATE_CLASSES)
regress_test_central = create_test_set(regress_test_federated_data, 1)
# Out:
# WARNING:tensorflow:From /tmp/ipykernel_334/775981372.py:11: sample_from_datasets_v2 (from tensorflow.python.data.experimental.ops.interleave_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.sample_from_datasets(...)`.
# WARNING:tensorflow:From /tmp/ipykernel_334/775981372.py:11: sample_from_datasets_v2 (from tensorflow.python.data.experimental.ops.interleave_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.sample_from_datasets(...)`.

# %%
type(phase_test_central)
# Out:
# tensorflow.python.data.ops.map_op._MapDataset

# %% [markdown]
# ### Evaluation functions

# %%
# Model compile instructions taken from Dandan's code
def evaluate_h1(server_state):
  model = build_h1_model()
  model.compile(
      loss='categorical_crossentropy',
      optimizer='adam',
      metrics=['accuracy']  
  )
  model.set_weights(server_state)
  model.evaluate(phase_test_central)

# %%
# Model compile instructions taken from Dandan's code
def evaluate_h2(server_state):
  model = build_h2_model()
  model.compile(
      loss='categorical_crossentropy',
      optimizer='adam',
      metrics=['accuracy']  
  )
  model.set_weights(server_state)
  model.evaluate(state_test_central)

# %%
# Model compile instructions taken from Dandan's code
def evaluate_h3(server_state):
  model = build_h3_model()
  model.compile(
      loss='mean_squared_error',
      optimizer='adam',
      metrics=['mse']  
  )
  model.set_weights(server_state)
  model.evaluate(regress_test_central)

# %% [markdown]
# ### H1

# %%
server_state_h1 = federated_algorithm_h1.initialize()
evaluate_h1(server_state_h1)
# Out:
# 2023-06-10 12:57:28.280992: I tensorflow/core/grappler/devices.cc:66] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0
# 2023-06-10 12:57:28.281234: I tensorflow/core/grappler/clusters/single_machine.cc:358] Starting new session
# 2023-06-10 12:57:31.375481: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_7' with dtype float and shape [42,50,50,3]
# 	 [[{{node Placeholder/_7}}]]
# 2023-06-10 12:57:31.376430: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_41' with dtype float and shape [50,4]
# 	 [[{{node Placeholder/_41}}]]
# 57/57 [==============================] - 5s 64ms/step - loss: 2.0125 - accuracy: 0.2246

# %% [markdown]
# ### H2

# %%
server_state_h2 = federated_algorithm_h2.initialize()
evaluate_h2(server_state_h2)
# Out:
# 2023-06-10 12:57:36.940932: I tensorflow/core/grappler/devices.cc:66] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0
# 2023-06-10 12:57:36.941081: I tensorflow/core/grappler/clusters/single_machine.cc:358] Starting new session
# 2023-06-10 12:57:38.377607: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_22' with dtype float and shape [44,50,50,3]
# 	 [[{{node Placeholder/_22}}]]
# 2023-06-10 12:57:38.378515: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_70' with dtype float and shape [39,50,50,3]
# 	 [[{{node Placeholder/_70}}]]
# 57/57 [==============================] - 5s 63ms/step - loss: 3.5214 - accuracy: 0.0693

# %% [markdown]
# ### H3

# %%
server_state_h3 = federated_algorithm_h3.initialize()
evaluate_h3(server_state_h3)
# Out:
# 2023-06-10 12:57:43.691192: I tensorflow/core/grappler/devices.cc:66] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0
# 2023-06-10 12:57:43.691321: I tensorflow/core/grappler/clusters/single_machine.cc:358] Starting new session
# 2023-06-10 12:57:45.695806: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_53' with dtype double and shape [53,1]
# 	 [[{{node Placeholder/_53}}]]
# 2023-06-10 12:57:45.696758: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_62' with dtype double and shape [53,1]
# 	 [[{{node Placeholder/_62}}]]
# 57/57 [==============================] - 5s 63ms/step - loss: 1.1061 - mse: 0.1464

# %% [markdown]
# ## Build Eval Models (TFF glitch)

# %%
h1_eval = build_h1_model()
h1_eval.compile(
      loss='categorical_crossentropy',
      optimizer='adam',
      metrics=['accuracy']  
  )

# %%
h2_eval = build_h2_model()
h2_eval.compile(
      loss='categorical_crossentropy',
      optimizer='adam',
      metrics=['accuracy']  
  )

# %%
h3_eval = build_h3_model()
h3_eval.compile(
    loss='mean_squared_error',
    optimizer='adam',
    metrics=['mse']  
)

# %% [markdown]
# ## Model Training

# %% [markdown]
# ### H1

# %%
with summary_writer_h1.as_default():
    for round in range(5):
        server_state_h1 = federated_algorithm_h1.next(server_state_h1, phase_train)
        # evaluation - run quietly
        h1_eval.set_weights(server_state_h1.model)
        loss, accuracy = h1_eval.evaluate(phase_test_central, verbose=0)
        print('round {:2d}, loss={:.3f}, accuracy={:.3f}'.format(round, loss, accuracy))
        # save the metrics
        tf.summary.scalar('loss', loss, step=round)
        tf.summary.scalar('accuracy', accuracy, step=round)

# %% [markdown]
# ### H2

# %%
with summary_writer_h2.as_default():
    for round in range(5):
        server_state_h2 = federated_algorithm_h2.next(server_state_h2, state_train)
        # evaluation
        h2_eval.set_weights(server_state_h2)  
        loss, accuracy = h2_eval.evaluate(state_test_central, verbose=0)
        print('round {:2d}, loss={:.3f}, accuracy={:.3f}'.format(round, loss, accuracy))
        # save the metrics
        tf.summary.scalar('loss', loss, step=round)
        tf.summary.scalar('accuracy', accuracy, step=round)
# Out:
# 2023-06-10 13:05:39.890113: I tensorflow/core/grappler/devices.cc:66] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0
# 2023-06-10 13:05:40.850377: I tensorflow/core/grappler/clusters/single_machine.cc:358] Starting new session
# 2023-06-10 13:05:41.868494: I tensorflow/core/grappler/devices.cc:66] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0
# 2023-06-10 13:05:41.868681: I tensorflow/core/grappler/clusters/single_machine.cc:358] Starting new session
# 2023-06-10 13:05:41.990673: I tensorflow/core/grappler/devices.cc:66] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0
# 2023-06-10 13:05:41.990917: I tensorflow/core/grappler/clusters/single_machine.cc:358] Starting new session
# 2023-06-10 13:05:42.237388: I tensorflow/core/grappler/devices.cc:66] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0
# 2023-06-10 13:05:42.237603: I tensorflow/core/grappler/clusters/single_machine.cc:358] Starting new session
# 2023-06-10 13:05:42.354361: I tensorflow/core/grappler/devices.cc:66] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0
# 2023-06-10 13:05:42.354525: I tensorflow/core/grappler/clusters/single_machine.cc:358] Starting new session
# 2023-06-10 13:05:42.590624: I tensorflow/core/grappler/devices.cc:66] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0
# 2023-06-10 13:05:42.590788: I tensorflow/core/grappler/clusters/single_machine.cc:358] Starting new session
# 2023-06-10 13:05:43.090210: I tensorflow/core/grappler/devices.cc:66] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0
# 2023-06-10 13:05:43.090574: I tensorflow/core/grappler/clusters/single_machine.cc:358] Starting new session
# 2023-06-10 13:05:43.502089: I tensorflow/core/grappler/devices.cc:66] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0
# 2023-06-10 13:05:43.502249: I tensorflow/core/grappler/clusters/single_machine.cc:358] Starting new session
# 2023-06-10 13:05:43.975071: I tensorflow/core/grappler/devices.cc:66] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0
# 2023-06-10 13:05:43.975647: I tensorflow/core/grappler/clusters/single_machine.cc:358] Starting new session

# %% [markdown]
# ### H3

# %%
with summary_writer_h3.as_default():
    for round in range(5):
        server_state_h3 = federated_algorithm_h3.next(server_state_h3, regress_train)
        # evaluation
        h3_eval.set_weights(server_state_h3)  
        loss, accuracy = h3_eval.evaluate(regress_test_central, verbose=0)
        print('round {:2d}, loss={:.3f}, accuracy={:.3f}'.format(round, loss, accuracy))
        # save the metrics
        tf.summary.scalar('loss', loss, step=round)
        tf.summary.scalar('accuracy', accuracy, step=round)
# Out:
# 2023-06-09 23:11:27.359409: I tensorflow/core/grappler/devices.cc:66] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0
# 2023-06-09 23:11:27.373792: I tensorflow/core/grappler/clusters/single_machine.cc:358] Starting new session
# 2023-06-09 23:11:29.262573: I tensorflow/core/grappler/devices.cc:66] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0
# 2023-06-09 23:11:29.262833: I tensorflow/core/grappler/clusters/single_machine.cc:358] Starting new session
# 2023-06-09 23:11:29.565037: I tensorflow/core/grappler/devices.cc:66] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0
# 2023-06-09 23:11:29.565267: I tensorflow/core/grappler/clusters/single_machine.cc:358] Starting new session
# 2023-06-09 23:11:30.042798: I tensorflow/core/grappler/devices.cc:66] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0
# 2023-06-09 23:11:30.042985: I tensorflow/core/grappler/clusters/single_machine.cc:358] Starting new session
# 2023-06-09 23:11:30.277731: I tensorflow/core/grappler/devices.cc:66] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0
# 2023-06-09 23:11:30.277983: I tensorflow/core/grappler/clusters/single_machine.cc:358] Starting new session
# 2023-06-09 23:11:30.727890: I tensorflow/core/grappler/devices.cc:66] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0
# 2023-06-09 23:11:30.728128: I tensorflow/core/grappler/clusters/single_machine.cc:358] Starting new session
# 2023-06-09 23:11:31.957991: I tensorflow/core/grappler/devices.cc:66] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0
# 2023-06-09 23:11:31.958187: I tensorflow/core/grappler/clusters/single_machine.cc:358] Starting new session
# 2023-06-09 23:11:32.658321: I tensorflow/core/grappler/devices.cc:66] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0
# 2023-06-09 23:11:32.658499: I tensorflow/core/grappler/clusters/single_machine.cc:358] Starting new session
# 2023-06-09 23:11:34.531418: I tensorflow/core/grappler/devices.cc:66] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0
# 2023-06-09 23:11:34.531731: I tensorflow/core/grappler/clusters/single_machine.cc:358] Starting new session

# %% [markdown]
# ## Post-Training evaluation

# %% [markdown]
# ### H1

# %%
h1_eval.set_weights(server_state_h1)
h1_eval.evaluate(phase_test_central)
# Out:
# 57/57 [==============================] - 17s 140ms/step - loss: 1.2908 - accuracy: 0.9254
# [1.290783405303955, 0.9254385828971863]

# %%
h1_eval.save('Models/h1_eval.h5')

# %% [markdown]
# ### H2

# %%
h2_eval.set_weights(server_state_h2)
h2_eval.evaluate(state_test_central)
# Out:
# 57/57 [==============================] - 10s 95ms/step - loss: 1.6620 - accuracy: 0.7798
# [1.662004828453064, 0.7798245549201965]

# %%
h2_eval.save('Models/h2_eval.h5')

# %% [markdown]
# ### H3

# %%
h3_eval.set_weights(server_state_h3)
h3_eval.evaluate(regress_test_central)
# Out:
# 57/57 [==============================] - 9s 98ms/step - loss: 1.0638 - mse: 0.1069
# [1.0638397932052612, 0.10685588419437408]

# %%
h3_eval.save('Models/h3_eval.h5')

# %% [markdown]
# ## Tensorboard Visualizations

# %%
# !ls {'Logs/H1/'}
# !tensorboard --logdir {'Logs/H1/'} --port=0

# %%
# !ls {'Logs/H2/'}
# !tensorboard --logdir {'Logs/H2/'} --port=0

# %%
# !ls {'Logs/H3/'}
# !tensorboard --logdir {'Logs/H3/'} --port=0
