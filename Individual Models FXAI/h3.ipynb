# %% [markdown]
# ## Note
# For this file to run successfully, it is necessary to have already trained H2. This file loads in the trained version of H2 to initialise the weights of the H3 model.

# %% [markdown]
# Much of the code used to implement federated learning is taken or adapted from https://www.tensorflow.org/federated/tutorials/building_your_own_federated_learning_algorithm

# %% [markdown]
# ## Mount Drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/Individual Models FXAI/
# Out:
# /content/drive/MyDrive/Individual Models FXAI

# %% [markdown]
# ## Env setup

# %%
# !pip install --quiet --upgrade tensorflow-federated
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 114.4/114.4 MB 15.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.6/60.6 kB 6.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 104.6/104.6 kB 12.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.7/98.7 kB 10.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 558.5/558.5 kB 46.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.6/71.6 MB 24.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 68.2 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 33.7/33.7 MB 51.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 255.8/255.8 kB 26.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 238.9/238.9 kB 24.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 365.2/365.2 kB 36.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.6/4.6 MB 97.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 86.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.4/7.4 MB 106.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.6/42.6 kB 4.2 MB/s eta 0:00:00
#   Building wheel for farmhashpy (setup.py) ... done
#   Building wheel for jax (pyproject.toml) ... done
#   Building wheel for sqlalchemy (setup.py) ... done
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# ipython-sql 0.5.0 requires sqlalchemy>=2.0, but you have sqlalchemy 1.4.0 which is incompatible.
# jsonschema 4.19.0 requires attrs>=22.2.0, but you have attrs 21.4.0 which is incompatible.
# pydantic 2.2.1 requires typing-extensions>=4.6.1, but you have typing-extensions 4.4.0 which is incompatible.
# pydantic-core 2.6.1 requires typing-extensions!=4.7.0,>=4.6.0, but you have typing-extensions 4.4.0 which is incompatible.
# pymc 5.7.2 requires cachetools>=4.2.1, but you have cachetools 3.1.1 which is incompatible.
# referencing 0.30.2 requires attrs>=22.2.0, but you have attrs 21.4.0 which is incompatible.

# %% [markdown]
# # Training H3

# %% [markdown]
# ## Imports

# %%
from __future__ import print_function

import tensorflow as tf
import tensorflow_federated as tff
import numpy as np
import collections
from tensorflow.keras.models import load_model

# From EHIL


import keras
from keras.layers.convolutional import ( Conv2D, MaxPooling2D, AveragePooling2D)
from keras.layers import (    Input,    Activation,    Dense,    Flatten)
from keras.layers import add
from keras.layers import LayerNormalization

from keras.regularizers import l2
from keras import backend as K
from keras.models import Model

from keras.preprocessing.image import ImageDataGenerator
from keras.callbacks import ReduceLROnPlateau, CSVLogger, EarlyStopping
from keras.callbacks import ModelCheckpoint, LearningRateScheduler
from keras.utils import np_utils

import os
import numpy as np

from sklearn.model_selection import train_test_split

import time
import datetime

import csv

# %% [markdown]
# ## Config

# %%
img_channels = 3
BATCH_SIZE = 20
NUM_CLIENTS = 25 #25
REGRESS_CLASSES = 1
EPOCHS = 1000
LOGS_DIR = 'H3'
MODEL_NAME = 'h3_25_clients_1000_epochs'
H2_MODEL_NAME = 'h2_25_clients_200_epochs'

##############################################################################

img_rows, img_cols = 256,256
img_rows, img_cols = 50,50

Cup_Type = 'Big'
if Cup_Type == 'Medium':
    nb_classes = 9
if Cup_Type == 'Big':
    nb_classes = 10
if Cup_Type == 'Small':
    nb_classes = 7

# %% [markdown]
# ## Load Data

# %%
NPZ_Name = 'Data/Videos_Database_20_Robot_WebCam_50_overall_database.npz'
Database_Used = np.load(NPZ_Name)
Sessions = Database_Used['Session']

# %%
# create a list of the unique sessions
client_ids = np.unique(Sessions)

# %%
# Several steps need to be completed to convert our data to a format suitable for tensorflow-federated operations
# The first is to create tf.data.Dataset objects
def create_tf_dataset(client_ids, Database_used_col, categorical, categories):
  train_datasets = []
  test_datasets = []
  for session in client_ids:
    # find the indices of the current session in the Sessions column of Database_Used
    session_indices = np.where(Sessions == session)[0]

    # get the X_train data for the current session
    session_X = Database_Used['X_train'][session_indices]
    # grab the training data for the necessary hierarchy
    session_Y = Database_Used[Database_used_col][session_indices]
    # if using categorical data, reshape the data for the model into one-hot encoded
    if categorical==True:
      session_Y = np_utils.to_categorical(session_Y, categories)
    # create train/test split
    X_train, X_test, Y_train, Y_test = train_test_split(session_X, session_Y, test_size=0.2, random_state=100)
    # Make into tf dataset
    train_dataset = tf.data.Dataset.from_tensor_slices((X_train,Y_train))
    test_dataset = tf.data.Dataset.from_tensor_slices((X_test, Y_test))
    # Add to our list of datasets
    train_datasets.append([session,train_dataset])
    test_datasets.append([session,test_dataset])
  return train_datasets, test_datasets

# %%
regress_train_datasets, regress_test_datasets = create_tf_dataset(client_ids, 'Y_train_Regress', False, None)

# %%
def make_client_data(datasets):
  client_data = {}
  # loop through the datasets
  for dataset in datasets:
      # get the session name
      session = dataset[0]

      # get the session data
      session_data = dataset[1]

      # add the session data to the client_data dictionary
      client_data[session] = session_data
  return client_data

# %%
# Make everything into a map for creating ClientData objects necessary for TFF federated learning

regress_train_client_data = make_client_data(regress_train_datasets)
regress_test_client_data = make_client_data(regress_test_datasets)

# %%
client_ids = list(client_ids)

# %% [markdown]
# ## Setup Federated Data

# %%
def make_federated_data(client_data, client_ids):
  # Need a function to get the client data in order to make ClientData object
  def get_client_dataset(client_id):
    return client_data[client_id]

  # use tff to create ClientData object from our training data
  federated_data = tff.simulation.datasets.ClientData.from_clients_and_tf_fn(client_ids, get_client_dataset)

  return federated_data

# %%
regress_train_federated_data = make_federated_data(regress_train_client_data, client_ids)
regress_test_federated_data = make_federated_data(regress_test_client_data, client_ids)

# %%
def preprocess(dataset, num_classes):
    def batch_format_fn(image, label):
        """Prepare a batch of data and return a (features, label) tuple."""
        batch_size = tf.shape(image)[0]  # Get the current batch size
        return (tf.reshape(image, [batch_size, 50, 50, 3]),
                tf.reshape(label, [batch_size, num_classes]))

    return dataset.batch(BATCH_SIZE).map(batch_format_fn)

def preprocess_federated_data(federated_data, num_classes):
  client_ids = sorted(federated_data.client_ids)[:NUM_CLIENTS]
  federated_data = [preprocess(federated_data.create_tf_dataset_for_client(x), num_classes)
                          for x in client_ids]
  return federated_data

# %%
regress_train = preprocess_federated_data(regress_train_federated_data, 1)

# %%
regress_train[0].element_spec
# Out:
# (TensorSpec(shape=(None, 50, 50, 3), dtype=tf.float32, name=None),
#  TensorSpec(shape=(None, 1), dtype=tf.float64, name=None))

# %% [markdown]
# ## Setup Model

# %% [markdown]
# ### Functions from Dandan's code

# %%
###############################################################################
'''
Functions
'''
###############################################################################

from keras.initializers import glorot_uniform

def lr_schedule(epoch):
    '''
    epoch: number of epochs for model training
    lr: learning rate
    '''
    lr = 1e-3
    if epoch > 160:
        lr *= 0.5e-3
    elif epoch > 120:
        lr *= 1e-3
    elif epoch > 80:
        lr *= 1e-2
    elif epoch > 40:
        lr *= 1e-1
    print('Learning rate: ', lr)
    return lr



def Conv_bn_relu(infor, **conv_params):
    '''
    Build conv -> BN -> relu block
    '''
    filters = conv_params["filters"]
    kernel_size = conv_params["kernel_size"]
    strides = conv_params.setdefault("strides", (1, 1))
    kernel_initializer = conv_params.setdefault("kernel_initializer", "he_normal")
    padding = conv_params.setdefault("padding", "same")
    kernel_regularizer = conv_params.setdefault("kernel_regularizer", l2(1.e-4))


    conv = Conv2D(filters=filters, kernel_size=kernel_size,
                  strides=strides, padding=padding,
                  kernel_initializer=kernel_initializer,
                  kernel_regularizer=kernel_regularizer)(infor)


    norm = LayerNormalization(axis=CHANNEL_AXIS)(conv)
    out = Activation("relu")(norm)

    return out


#Reference: http://arxiv.org/pdf/1603.05027v2.pdf
def Bn_relu_conv(infor,**conv_params):
    '''
    Build a BN -> relu -> conv block.
    '''
    filters = conv_params["filters"]
    kernel_size = conv_params["kernel_size"]
    strides = conv_params.setdefault("strides", (1, 1))
    kernel_initializer = conv_params.setdefault("kernel_initializer", "he_normal")
    padding = conv_params.setdefault("padding", "same")
    kernel_regularizer = conv_params.setdefault("kernel_regularizer", l2(1.e-4))

    norm = LayerNormalization(axis=CHANNEL_AXIS)(infor)

    activation = Activation("relu")(norm)

    out = Conv2D(filters=filters, kernel_size=kernel_size,
                      strides=strides, padding=padding,
                      kernel_initializer=kernel_initializer,
                      kernel_regularizer=kernel_regularizer)(activation)

    return out



def basic_block(BlockIn, filters, init_strides=(1, 1), is_first_block_of_first_layer=False):
    '''
    Basic 3 X 3 convolution blocks
    '''

    if is_first_block_of_first_layer:
        conv1 = Conv2D(filters=filters, kernel_size=(3, 3),
                       strides=init_strides,
                       padding="same",
                       kernel_initializer="he_normal",
                       kernel_regularizer=l2(1e-4))(BlockIn)
    else:
        conv1 = Bn_relu_conv(infor = BlockIn,filters=filters, kernel_size=(3, 3),
                              strides=init_strides)

    residual = Bn_relu_conv(infor = conv1,filters=filters, kernel_size=(3, 3))


    input_shape = K.int_shape(BlockIn)
    residual_shape = K.int_shape(residual)

    # stride should be set properly and match  (width, height) of residual
    stride_width = int(round(input_shape[ROW_AXIS] / residual_shape[ROW_AXIS]))
    stride_height = int(round(input_shape[COL_AXIS] / residual_shape[COL_AXIS]))


    equal_channels = input_shape[CHANNEL_AXIS] == residual_shape[CHANNEL_AXIS]


    if stride_width > 1 or stride_height > 1 or not equal_channels:
        shortcut = Conv2D(filters=residual_shape[CHANNEL_AXIS],
                          kernel_size=(1, 1),
                          strides=(stride_width, stride_height),
                          padding="valid",
                          kernel_initializer="he_normal",
                          kernel_regularizer=l2(0.0001))(BlockIn)
    else:
        shortcut = BlockIn

    # Adds a shortcut between input and residual block
    return add([shortcut, residual])


def buildmodel(input_shape, num_outputs, Regress_Flag):
        '''

        input_shape: (nb_channels, nb_rows, nb_cols)
        num_outputs:  number of outputs at final softmax layer
        Regress_Flag: classify or regress

        '''

        global ROW_AXIS
        global COL_AXIS
        global CHANNEL_AXIS

        # if K.image_data_format() == 'channels_last':

        #     ROW_AXIS = 1; COL_AXIS = 2;  CHANNEL_AXIS = 3
        # else:
        #     CHANNEL_AXIS = 1; ROW_AXIS = 2; COL_AXIS = 3

        if tf.keras.backend.image_data_format() == 'channels_last':
            ROW_AXIS = 1
            COL_AXIS = 2
            CHANNEL_AXIS = 3
        else:
            CHANNEL_AXIS = 1
            ROW_AXIS = 2
            COL_AXIS = 3



        if len(input_shape) != 3:
            raise Exception("Input shape should be a tuple (nb_channels, nb_rows, nb_cols)")

        # Permute dimension order if necessary
        if K.image_data_format() == 'channels_last':
        #if K.image_dim_ordering() == 'tf':

            input_shape = (input_shape[1], input_shape[2], input_shape[0])

        input = Input(shape=input_shape, name='main_input')
        conv1 = Conv_bn_relu(input, filters=64, kernel_size=(7, 7), strides=(2, 2))
        pool1 = MaxPooling2D(pool_size=(3, 3), strides=(2, 2), padding="same", name = "conv_pool1")(conv1)

        block = pool1
        filters = 64
        for i, r in enumerate([2,2,2,2]):
            '''
            residual block with repeating bottleneck blocks
            '''

            is_first_layer=(i == 0)
            for i in range(r):
                init_strides = (1, 1)
                if i == 0 and not is_first_layer:
                    init_strides = (2, 2)
                block = basic_block(BlockIn = block, filters=filters, init_strides=init_strides,
                                       is_first_block_of_first_layer=(is_first_layer and i == 0))

            filters *= 2

        # Last activation

        norm = LayerNormalization(axis=CHANNEL_AXIS)(block)
        block = Activation("relu")(norm)

        # classifier block
        block_shape = K.int_shape(block)
        pool2_out = AveragePooling2D(pool_size=(block_shape[ROW_AXIS], block_shape[COL_AXIS]),
                                 strides=(1, 1), name = "conv_final")(block)

        #flatten1 = keras.layers.GlobalAveragePooling2D(name = "GAP")(pool2)
        #out = keras.layers.Dense(num_outputs,activation='softmax')(pooled)

        flatten1 = Flatten( name = "Flatten")(pool2_out)

        flatten1 = Dense(128, activation='relu',name = "Flatten2")(flatten1)

        if Regress_Flag == False:

            dense = Dense(units=num_outputs, kernel_initializer="he_normal",
                      activation="softmax", name = "Dense_layer")(flatten1)
        else:
            dense = Dense(units=1, activation='linear', kernel_initializer=glorot_uniform(seed=0))(flatten1)

            #dense = Dense(units=1, kernel_initializer="he_normal", activation="linear", name = "Dense_layer")(flatten1)

        model = Model(inputs=input, outputs=dense)
        return model


def learn_model(oldmodel,nb_classes,Transfer_Type,summary=False):

    base_model = oldmodel

    if Transfer_Type == 'Classification':
        intermediate_layer_model = Model(inputs=base_model.input,outputs=base_model.get_layer("conv_final").output)

    if Transfer_Type == 'Regression':
        #intermediate_layer_model = Model(inputs=base_model.input,outputs=base_model.get_layer("Flatten1").output)
        intermediate_layer_model = Model(inputs=base_model.input,outputs=base_model.get_layer("Dense_Classification").output)

    x = intermediate_layer_model(base_model.input)
    if nb_classes >1:
        x = keras.layers.GlobalAveragePooling2D()(x)# 添加全局平均池化层
    x = Dense(128, activation='relu')(x)
    x = Dense(64, activation='relu')(x)


    if Transfer_Type == 'Classification':
        dense = Dense(units=nb_classes, kernel_initializer="he_normal",
                  activation="softmax", name = "Dense_Classification")(x)
    if Transfer_Type == 'Regression':
        dense = Dense(units=1, activation='linear', name = "Dense_Regression", kernel_initializer=glorot_uniform(seed=0))(x)

    model = Model(inputs=base_model.input, outputs=dense)


    # show summary if specified
    if summary==True :
        model.summary()

    if Transfer_Type == 'Classification':
        # choose the optimizer
        #optimizer = keras.optimizers.Adam()
        model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

    if Transfer_Type == 'Regression':
        model.compile(loss = 'mean_squared_error', optimizer = 'adam', metrics=['mse'])

    return model

# %% [markdown]
# ### Load From H2 Model

# %%
# We need the model weights from training H2 to initialise the H3 model
h2_model = keras.models.load_model('Models/' + H2_MODEL_NAME + '.h5')
h3_model = learn_model(h2_model, REGRESS_CLASSES, 'Regression',False)

# It makes the implementation simpler to remove any arguments from the model building function
def build_h3_model():
  return tf.keras.models.clone_model(h3_model)

# %%
# View the model architecture
model = build_h3_model()
keras.utils.plot_model(model, expand_nested=True, dpi=60, show_shapes=True)

# %%
model.summary()
# Out:
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  main_input (InputLayer)     [(None, 50, 50, 3)]       0
#
#  model (Functional)          (None, 10)                11254090
#
#  dense (Dense)               (None, 128)               1408
#
#  dense_1 (Dense)             (None, 64)                8256
#
#  Dense_Regression (Dense)    (None, 1)                 65
#
# =================================================================
# Total params: 11,263,819
# Trainable params: 11,263,819
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## Setup Federated Learning

# %% [markdown]
# ### Tensorflow Federated Learning Functions

# %%
def model_fn_h3():
  model = build_h3_model()
  return tff.learning.models.from_keras_model(
      model,
      input_spec=regress_train[0].element_spec,
      loss=tf.keras.losses.MeanSquaredError(),
      metrics=[tf.keras.metrics.MeanSquaredError()])

# %%
@tff.tf_computation
def server_init_h3():
  model = model_fn_h3()
  return model.trainable_variables

# %%
@tff.federated_computation
def initialize_fn_h3():
  return tff.federated_value(server_init_h3(), tff.SERVER)

# %%
@tf.function
def client_update_h3(model, dataset, server_weights, client_optimizer):
  """Performs training (using the server model weights) on the client's dataset."""
  # Initialize the client model with the current server weights.
  client_weights = model.trainable_variables
  # Assign the server weights to the client model.
  tf.nest.map_structure(lambda x, y: x.assign(y),
                        client_weights, server_weights)

  # Use the client_optimizer to update the local model.
  for batch in dataset:
    with tf.GradientTape() as tape:
      # Compute a forward pass on the batch of data
      outputs = model.forward_pass(batch)

    # Compute the corresponding gradient
    grads = tape.gradient(outputs.loss, client_weights)
    grads_and_vars = zip(grads, client_weights)

    # Apply the gradient using a client optimizer.
    client_optimizer.apply_gradients(grads_and_vars)

  return client_weights

# %%
@tf.function
def server_update_h3(model, mean_client_weights):
  """Updates the server model weights as the average of the client model weights."""
  model_weights = model.trainable_variables
  # Assign the mean client weights to the server model.
  tf.nest.map_structure(lambda x, y: x.assign(y),
                        model_weights, mean_client_weights)
  return model_weights

# %%
h3_fed = model_fn_h3()
tf_dataset_type_h3 = tff.SequenceType(h3_fed.input_spec)

# %%
str(tf_dataset_type_h3)
# Out:
# '<float32[?,50,50,3],float64[?,1]>*'

# %%
model_weights_type_h3 = h3_fed.trainable_variables
# Assuming model_weights_type is a list of trainable variables
model_weights_type_h3 = [v for v in model_weights_type_h3]

model_weights_type_h3 = tff.to_type([tf.TensorSpec.from_tensor(v.value()) for v in model_weights_type_h3])

# %%
@tff.tf_computation(tf_dataset_type_h3, model_weights_type_h3)
def client_update_fn_h3(tf_dataset, server_weights):
  model = model_fn_h3()
  client_optimizer = tf.keras.optimizers.SGD(learning_rate=0.01)
  return client_update_h3(model, tf_dataset, server_weights, client_optimizer)

# %%
@tff.tf_computation(model_weights_type_h3)
def server_update_fn_h3(mean_client_weights):
  model = model_fn_h3()
  return server_update_h3(model, mean_client_weights)

# %%
federated_server_type_h3 = tff.FederatedType(model_weights_type_h3, tff.SERVER)
federated_dataset_type_h3 = tff.FederatedType(tf_dataset_type_h3, tff.CLIENTS)

# %%
@tff.federated_computation(federated_server_type_h3, federated_dataset_type_h3)
def next_fn_h3(server_weights, federated_dataset):
  # Broadcast the server weights to the clients.
  server_weights_at_client = tff.federated_broadcast(server_weights)

  # Each client computes their updated weights.
  client_weights = tff.federated_map(
      client_update_fn_h3, (federated_dataset, server_weights_at_client))

  # The server averages these updates.
  mean_client_weights = tff.federated_mean(client_weights)

  # The server updates its model.
  server_weights = tff.federated_map(server_update_fn_h3, mean_client_weights)

  return server_weights

# %%
federated_algorithm_h3 = tff.templates.IterativeProcess(
    initialize_fn=initialize_fn_h3,
    next_fn=next_fn_h3
)

# %% [markdown]
# ### Creating test set

# %%
def create_test_set(federated_test_set, num_classes):
  # Create a list to store client datasets
  client_datasets = []

  # Iterate over client IDs and create datasets
  for client_id in sorted(federated_test_set.client_ids)[:NUM_CLIENTS]:
      client_dataset = federated_test_set.create_tf_dataset_for_client(client_id)
      client_datasets.append(client_dataset)

  # Combine the client datasets into a centralized dataset
  test_set = tf.data.experimental.sample_from_datasets(client_datasets)
  test_set = preprocess(test_set, num_classes)
  return test_set

# %%
regress_test_central = create_test_set(regress_test_federated_data, 1)
regress_train_central = create_test_set(regress_train_federated_data, 1)
# Out:
# WARNING:tensorflow:From <ipython-input-35-6107c5ce5802>:11: sample_from_datasets_v2 (from tensorflow.python.data.experimental.ops.interleave_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.sample_from_datasets(...)`.

# %% [markdown]
# ### Evaluation Function

# %%
# Model compile instructions taken from Dandan's code
def evaluate_h3(server_state):
  model = build_h3_model()
  model.compile(
      loss='mean_squared_error',
      optimizer='adam',
      metrics=['mse']
  )
  model.set_weights(server_state)
  model.evaluate(regress_test_central)

# %%
# Initialize server state and conduct initial evaluation
server_state_h3 = federated_algorithm_h3.initialize()
# evaluate_h3(server_state_h3)

# %% [markdown]
# ### Build Eval Model

# %% [markdown]
# Due to the way tensorflow federated works, we will not be able to create new models once the training has begun. For this reason, we create the evaluaiton model before the training. This also allows us to track the performance of the model through training.

# %%
h3_eval = build_h3_model()
h3_eval.compile(
    loss='mean_squared_error',
    optimizer='adam',
    metrics=['mse']
)

# %% [markdown]
# ## Time Logging for training

# %%
def format_time(seconds):
    hours, remainder = divmod(seconds, 3600)
    minutes, seconds = divmod(remainder, 60)
    return "{:02d}:{:02d}:{:02d}".format(int(hours), int(minutes), int(seconds))

def calculate_time(round, start_time, times_taken, total_rounds):
    # Record the end time for the current round
    end_time = time.time()
    # Calculate the time taken for the current round
    time_taken = end_time - start_time
    # Append the time taken to the list of times
    times_taken.append(time_taken)

    # Calculate the average time taken for the previous rounds
    avg_time_taken = sum(times_taken) / len(times_taken)
    # Calculate the estimated remaining time for the remaining rounds
    remaining_rounds = total_rounds - (round + 1)
    estimated_remaining_time = remaining_rounds * avg_time_taken

    # Display the time taken for the current round and the estimated remaining time
    print('Time taken for round {:2d}: {}'.format(round, format_time(time_taken)))
    print('Estimated remaining time: {}'.format(format_time(estimated_remaining_time)))
    print('')

# %% [markdown]
# ## Training

# %% [markdown]
# ### Early stopping check

# %%
def early_stop_check(mse, best_mse, epochs_without_improvement):
  improvement = best_mse - mse
  if improvement > MIN_IMPROVEMENT:
      best_mse = mse
      epochs_without_improvement = 0
  else:
      epochs_without_improvement += 1
  # Stop training if no improvement for PATIENCE epochs
  if epochs_without_improvement >= PATIENCE:
      print("Early stopping: No improvement of at least {} for {} epochs.".format(MIN_IMPROVEMENT, PATIENCE))
      return True
  return False

# %% [markdown]
# ### Training Loop

# %%
# Define the early stopping parameters
PATIENCE = 10  # Number of epochs to wait for improvement
MIN_IMPROVEMENT = 0.001  # Minimum improvement threshold (adjust as needed)
best_mse = 100
epochs_without_improvement = 0


# Open the CSV file for writing
csv_file_path = 'logs' + '/' + LOGS_DIR + '/' + MODEL_NAME + '_train_test' + '.csv'
csv_columns = ['Round', 'Global_Train_Loss', 'Global_Train_MSE', 'Global_Test_Loss', 'Global_Test_MSE']  # Add more columns as needed

for client_id in client_ids:
    csv_columns.extend([f'{client_id}_Test_Loss', f'{client_id}_Test_MSE', f'{client_id}_Train_Loss', f'{client_id}_Train_MSE'])



# Write the CSV header
with open(csv_file_path, 'w', newline='') as csv_file:
    csv_writer = csv.DictWriter(csv_file, fieldnames=csv_columns)
    csv_writer.writeheader()
    times_taken = []
    for round in range(1, EPOCHS+1):
        start_time = time.time()

        # Set the server weights to be the result of performing federated averaging
        # on the client weights after one epoch of training.
        server_state_h3 = federated_algorithm_h3.next(server_state_h3, regress_train)

        # Conduct an evaluation of the training epoch
        h3_eval.set_weights(server_state_h3)
        global_train_loss, global_train_mse = h3_eval.evaluate(regress_train_central, verbose=0)
        global_test_loss, global_test_mse = h3_eval.evaluate(regress_test_central, verbose=0)
        print('Round {:2d}: \t global_test_loss={:.4f}, global_test_mse={:.4f} \n\t\tglobal_train_loss={:.4f}, global_train_mse={:.4f}'
              .format(round, global_test_loss, global_test_mse, global_train_loss, global_train_mse))

        # Early stopping check
        stop = early_stop_check(global_test_mse, best_mse, epochs_without_improvement)

        # Evaluate the model on a per-client basis
        client_metrics = {}
        for client_id in client_ids:
            client_dataset = regress_test_federated_data.create_tf_dataset_for_client(client_id)
            client_dataset = preprocess(client_dataset, REGRESS_CLASSES)
            test_loss, test_mse = h3_eval.evaluate(client_dataset, verbose=0)

            client_dataset = regress_train_federated_data.create_tf_dataset_for_client(client_id)
            client_dataset = preprocess(client_dataset, REGRESS_CLASSES)
            train_loss, train_mse = h3_eval.evaluate(client_dataset, verbose=0)

            # Save the metrics for each client
            client_metrics[f'{client_id}_Test_Loss'] = test_loss
            client_metrics[f'{client_id}_Test_MSE'] = test_mse
            client_metrics[f'{client_id}_Train_Loss'] = train_loss
            client_metrics[f'{client_id}_Train_MSE'] = train_mse

        # Save the metrics to CSV
        csv_row=({
            'Round': round,
            'Global_Train_Loss': global_train_loss,
            'Global_Train_MSE': global_train_mse,
            'Global_Test_Loss': global_test_loss,
            'Global_Test_MSE': global_test_mse,
            **client_metrics
        })

        csv_writer.writerow(csv_row)
        # Call the function to calculate time and display information
        calculate_time(round, start_time, times_taken, EPOCHS+1)

        # Stop if converged early
        if stop:
          print('Stopping criterea reached - Exiting training loop')
          break
# Out:
# Round  1: 	 global_test_loss=1.1013, global_test_mse=0.1411
# 		global_train_loss=1.1145, global_train_mse=0.1543
# Time taken for round  1: 00:00:51
# Estimated remaining time: 14:11:36
#
# Round  2: 	 global_test_loss=1.1002, global_test_mse=0.1401
# 		global_train_loss=1.1134, global_train_mse=0.1533
# Time taken for round  2: 00:00:35
# Estimated remaining time: 11:57:47
#
# Round  3: 	 global_test_loss=1.0991, global_test_mse=0.1390
# 		global_train_loss=1.1122, global_train_mse=0.1522
# Time taken for round  3: 00:00:35
# Estimated remaining time: 11:16:34
#
# Round  4: 	 global_test_loss=1.0975, global_test_mse=0.1375
# 		global_train_loss=1.1106, global_train_mse=0.1506
# Time taken for round  4: 00:00:35
# Estimated remaining time: 10:53:31
#
# Round  5: 	 global_test_loss=1.0952, global_test_mse=0.1352
# 		global_train_loss=1.1082, global_train_mse=0.1482
# Time taken for round  5: 00:00:35
# Estimated remaining time: 10:38:26
#
# Round  6: 	 global_test_loss=1.0925, global_test_mse=0.1325
# 		global_train_loss=1.1055, global_train_mse=0.1455
# Time taken for round  6: 00:00:34
# Estimated remaining time: 10:27:12
#
# Round  7: 	 global_test_loss=1.0902, global_test_mse=0.1303
# 		global_train_loss=1.1031, global_train_mse=0.1432
# Time taken for round  7: 00:00:34
# Estimated remaining time: 10:19:46
#
# Round  8: 	 global_test_loss=1.0881, global_test_mse=0.1282
# 		global_train_loss=1.1009, global_train_mse=0.1410
# Time taken for round  8: 00:00:34
# Estimated remaining time: 10:13:30
#
# Round  9: 	 global_test_loss=1.0862, global_test_mse=0.1264
# 		global_train_loss=1.0988, global_train_mse=0.1390
# Time taken for round  9: 00:00:34
# Estimated remaining time: 10:08:38
#
# Round 10: 	 global_test_loss=1.0845, global_test_mse=0.1247
# 		global_train_loss=1.0970, global_train_mse=0.1372
# Time taken for round 10: 00:00:34
# Estimated remaining time: 10:04:31
#
# Round 11: 	 global_test_loss=1.0830, global_test_mse=0.1232
# 		global_train_loss=1.0953, global_train_mse=0.1355
# Time taken for round 11: 00:00:34
# Estimated remaining time: 10:00:29
#
# Round 12: 	 global_test_loss=1.0815, global_test_mse=0.1218
# 		global_train_loss=1.0937, global_train_mse=0.1339
# Time taken for round 12: 00:00:34
# Estimated remaining time: 09:57:52
#
# Round 13: 	 global_test_loss=1.0800, global_test_mse=0.1203
# 		global_train_loss=1.0921, global_train_mse=0.1324
# Time taken for round 13: 00:00:34
# Estimated remaining time: 09:54:24
#
# Round 14: 	 global_test_loss=1.0788, global_test_mse=0.1191
# 		global_train_loss=1.0907, global_train_mse=0.1310
# Time taken for round 14: 00:00:34
# Estimated remaining time: 09:51:58
#
# Round 15: 	 global_test_loss=1.0776, global_test_mse=0.1180
# 		global_train_loss=1.0894, global_train_mse=0.1298
# Time taken for round 15: 00:00:34
# Estimated remaining time: 09:49:48
#
# Round 16: 	 global_test_loss=1.0766, global_test_mse=0.1170
# 		global_train_loss=1.0883, global_train_mse=0.1287
# Time taken for round 16: 00:00:34
# Estimated remaining time: 09:47:50
#
# Round 17: 	 global_test_loss=1.0757, global_test_mse=0.1161
# 		global_train_loss=1.0872, global_train_mse=0.1277
# Time taken for round 17: 00:00:35
# Estimated remaining time: 09:46:58
#
# Round 18: 	 global_test_loss=1.0748, global_test_mse=0.1152
# 		global_train_loss=1.0862, global_train_mse=0.1267
# Time taken for round 18: 00:00:34
# Estimated remaining time: 09:45:28
#
# Round 19: 	 global_test_loss=1.0740, global_test_mse=0.1145
# 		global_train_loss=1.0853, global_train_mse=0.1258
# Time taken for round 19: 00:00:35
# Estimated remaining time: 09:44:22
#
# Round 20: 	 global_test_loss=1.0732, global_test_mse=0.1137
# 		global_train_loss=1.0844, global_train_mse=0.1250
# Time taken for round 20: 00:00:34
# Estimated remaining time: 09:43:00
#
# Round 21: 	 global_test_loss=1.0725, global_test_mse=0.1131
# 		global_train_loss=1.0836, global_train_mse=0.1242
# Time taken for round 21: 00:00:34
# Estimated remaining time: 09:41:33
#
# Round 22: 	 global_test_loss=1.0718, global_test_mse=0.1124
# 		global_train_loss=1.0828, global_train_mse=0.1234
# Time taken for round 22: 00:00:34
# Estimated remaining time: 09:40:24
#
# Round 23: 	 global_test_loss=1.0711, global_test_mse=0.1117
# 		global_train_loss=1.0820, global_train_mse=0.1227
# Time taken for round 23: 00:00:34
# Estimated remaining time: 09:39:09
#
# Round 24: 	 global_test_loss=1.0704, global_test_mse=0.1111
# 		global_train_loss=1.0813, global_train_mse=0.1220
# Time taken for round 24: 00:00:34
# Estimated remaining time: 09:38:00
#
# Round 25: 	 global_test_loss=1.0698, global_test_mse=0.1105
# 		global_train_loss=1.0806, global_train_mse=0.1213
# Time taken for round 25: 00:00:34
# Estimated remaining time: 09:36:42
#
# Round 26: 	 global_test_loss=1.0692, global_test_mse=0.1100
# 		global_train_loss=1.0799, global_train_mse=0.1207
# Time taken for round 26: 00:00:34
# Estimated remaining time: 09:35:29
#
# Round 27: 	 global_test_loss=1.0687, global_test_mse=0.1095
# 		global_train_loss=1.0793, global_train_mse=0.1201
# Time taken for round 27: 00:00:34
# Estimated remaining time: 09:34:27
#
# Round 28: 	 global_test_loss=1.0681, global_test_mse=0.1089
# 		global_train_loss=1.0786, global_train_mse=0.1195
# Time taken for round 28: 00:00:34
# Estimated remaining time: 09:33:25
#
# Round 29: 	 global_test_loss=1.0676, global_test_mse=0.1084
# 		global_train_loss=1.0780, global_train_mse=0.1189
# Time taken for round 29: 00:00:34
# Estimated remaining time: 09:32:11
#
# Round 30: 	 global_test_loss=1.0670, global_test_mse=0.1079
# 		global_train_loss=1.0774, global_train_mse=0.1183
# Time taken for round 30: 00:00:34
# Estimated remaining time: 09:31:06
#
# Round 31: 	 global_test_loss=1.0665, global_test_mse=0.1074
# 		global_train_loss=1.0768, global_train_mse=0.1177
# Time taken for round 31: 00:00:34
# Estimated remaining time: 09:29:59
#
# Round 32: 	 global_test_loss=1.0660, global_test_mse=0.1069
# 		global_train_loss=1.0762, global_train_mse=0.1172
# Time taken for round 32: 00:00:34
# Estimated remaining time: 09:28:57
#
# Round 33: 	 global_test_loss=1.0654, global_test_mse=0.1064
# 		global_train_loss=1.0756, global_train_mse=0.1166
# Time taken for round 33: 00:00:34
# Estimated remaining time: 09:28:00
#
# Round 34: 	 global_test_loss=1.0649, global_test_mse=0.1059
# 		global_train_loss=1.0750, global_train_mse=0.1161
# Time taken for round 34: 00:00:34
# Estimated remaining time: 09:26:54
#
# Round 35: 	 global_test_loss=1.0644, global_test_mse=0.1055
# 		global_train_loss=1.0744, global_train_mse=0.1155
# Time taken for round 35: 00:00:34
# Estimated remaining time: 09:25:53
#
# Round 36: 	 global_test_loss=1.0638, global_test_mse=0.1050
# 		global_train_loss=1.0738, global_train_mse=0.1149
# Time taken for round 36: 00:00:34
# Estimated remaining time: 09:25:05
#
# Round 37: 	 global_test_loss=1.0633, global_test_mse=0.1044
# 		global_train_loss=1.0732, global_train_mse=0.1144
# Time taken for round 37: 00:00:34
# Estimated remaining time: 09:24:23
#
# Round 38: 	 global_test_loss=1.0627, global_test_mse=0.1039
# 		global_train_loss=1.0726, global_train_mse=0.1138
# Time taken for round 38: 00:00:34
# Estimated remaining time: 09:23:34
#
# Round 39: 	 global_test_loss=1.0622, global_test_mse=0.1034
# 		global_train_loss=1.0719, global_train_mse=0.1132
# Time taken for round 39: 00:00:34
# Estimated remaining time: 09:22:38
#
# Round 40: 	 global_test_loss=1.0616, global_test_mse=0.1029
# 		global_train_loss=1.0713, global_train_mse=0.1126
# Time taken for round 40: 00:00:34
# Estimated remaining time: 09:21:58
#
# Round 41: 	 global_test_loss=1.0610, global_test_mse=0.1023
# 		global_train_loss=1.0707, global_train_mse=0.1120
# Time taken for round 41: 00:00:34
# Estimated remaining time: 09:21:10
#
# Round 42: 	 global_test_loss=1.0605, global_test_mse=0.1018
# 		global_train_loss=1.0700, global_train_mse=0.1114
# Time taken for round 42: 00:00:34
# Estimated remaining time: 09:20:13
#
# Round 43: 	 global_test_loss=1.0599, global_test_mse=0.1012
# 		global_train_loss=1.0694, global_train_mse=0.1108
# Time taken for round 43: 00:00:34
# Estimated remaining time: 09:19:22
#
# Round 44: 	 global_test_loss=1.0593, global_test_mse=0.1007
# 		global_train_loss=1.0687, global_train_mse=0.1102
# Time taken for round 44: 00:00:34
# Estimated remaining time: 09:18:39
#
# Round 45: 	 global_test_loss=1.0587, global_test_mse=0.1001
# 		global_train_loss=1.0681, global_train_mse=0.1095
# Time taken for round 45: 00:00:34
# Estimated remaining time: 09:17:49
#
# Round 46: 	 global_test_loss=1.0581, global_test_mse=0.0996
# 		global_train_loss=1.0674, global_train_mse=0.1089
# Time taken for round 46: 00:00:34
# Estimated remaining time: 09:16:58
#
# Round 47: 	 global_test_loss=1.0575, global_test_mse=0.0990
# 		global_train_loss=1.0667, global_train_mse=0.1083
# Time taken for round 47: 00:00:34
# Estimated remaining time: 09:16:08
#
# Round 48: 	 global_test_loss=1.0569, global_test_mse=0.0985
# 		global_train_loss=1.0661, global_train_mse=0.1077
# Time taken for round 48: 00:00:34
# Estimated remaining time: 09:15:27
#
# Round 49: 	 global_test_loss=1.0564, global_test_mse=0.0980
# 		global_train_loss=1.0655, global_train_mse=0.1071
# Time taken for round 49: 00:00:34
# Estimated remaining time: 09:14:35
#
# Round 50: 	 global_test_loss=1.0558, global_test_mse=0.0974
# 		global_train_loss=1.0648, global_train_mse=0.1064
# Time taken for round 50: 00:00:34
# Estimated remaining time: 09:13:41
#
# Round 51: 	 global_test_loss=1.0552, global_test_mse=0.0969
# 		global_train_loss=1.0641, global_train_mse=0.1058
# Time taken for round 51: 00:00:33
# Estimated remaining time: 09:12:43
#
# Round 52: 	 global_test_loss=1.0546, global_test_mse=0.0963
# 		global_train_loss=1.0635, global_train_mse=0.1052
# Time taken for round 52: 00:00:34
# Estimated remaining time: 09:11:55
#
# Round 53: 	 global_test_loss=1.0541, global_test_mse=0.0958
# 		global_train_loss=1.0629, global_train_mse=0.1046
# Time taken for round 53: 00:00:34
# Estimated remaining time: 09:11:17
#
# Round 54: 	 global_test_loss=1.0535, global_test_mse=0.0953
# 		global_train_loss=1.0622, global_train_mse=0.1040
# Time taken for round 54: 00:00:33
# Estimated remaining time: 09:10:23
#
# Round 55: 	 global_test_loss=1.0530, global_test_mse=0.0948
# 		global_train_loss=1.0616, global_train_mse=0.1034
# Time taken for round 55: 00:00:34
# Estimated remaining time: 09:09:39
#
# Round 56: 	 global_test_loss=1.0524, global_test_mse=0.0942
# 		global_train_loss=1.0609, global_train_mse=0.1028
# Time taken for round 56: 00:00:33
# Estimated remaining time: 09:08:48
#
# Round 57: 	 global_test_loss=1.0519, global_test_mse=0.0937
# 		global_train_loss=1.0603, global_train_mse=0.1022
# Time taken for round 57: 00:00:34
# Estimated remaining time: 09:08:01
#
# Round 58: 	 global_test_loss=1.0512, global_test_mse=0.0932
# 		global_train_loss=1.0596, global_train_mse=0.1016
# Time taken for round 58: 00:00:33
# Estimated remaining time: 09:07:07
#
# Round 59: 	 global_test_loss=1.0506, global_test_mse=0.0926
# 		global_train_loss=1.0590, global_train_mse=0.1009
# Time taken for round 59: 00:00:34
# Estimated remaining time: 09:06:20
#
# Round 60: 	 global_test_loss=1.0500, global_test_mse=0.0920
# 		global_train_loss=1.0583, global_train_mse=0.1003
# Time taken for round 60: 00:00:34
# Estimated remaining time: 09:05:34
#
# Round 61: 	 global_test_loss=1.0494, global_test_mse=0.0915
# 		global_train_loss=1.0576, global_train_mse=0.0997
# Time taken for round 61: 00:00:34
# Estimated remaining time: 09:04:51
#
# Round 62: 	 global_test_loss=1.0489, global_test_mse=0.0910
# 		global_train_loss=1.0570, global_train_mse=0.0991
# Time taken for round 62: 00:00:34
# Estimated remaining time: 09:04:07
#
# Round 63: 	 global_test_loss=1.0482, global_test_mse=0.0903
# 		global_train_loss=1.0563, global_train_mse=0.0984
# Time taken for round 63: 00:00:33
# Estimated remaining time: 09:03:15
#
# Round 64: 	 global_test_loss=1.0480, global_test_mse=0.0901
# 		global_train_loss=1.0559, global_train_mse=0.0981
# Time taken for round 64: 00:00:34
# Estimated remaining time: 09:02:41
#
# Round 65: 	 global_test_loss=1.0474, global_test_mse=0.0896
# 		global_train_loss=1.0553, global_train_mse=0.0974
# Time taken for round 65: 00:00:34
# Estimated remaining time: 09:02:00
#
# Round 66: 	 global_test_loss=1.0468, global_test_mse=0.0890
# 		global_train_loss=1.0546, global_train_mse=0.0968
# Time taken for round 66: 00:00:34
# Estimated remaining time: 09:01:24
#
# Round 67: 	 global_test_loss=1.0462, global_test_mse=0.0884
# 		global_train_loss=1.0539, global_train_mse=0.0961
# Time taken for round 67: 00:00:34
# Estimated remaining time: 09:00:40
#
# Round 68: 	 global_test_loss=1.0455, global_test_mse=0.0878
# 		global_train_loss=1.0532, global_train_mse=0.0955
# Time taken for round 68: 00:00:34
# Estimated remaining time: 08:59:57
#
# Round 69: 	 global_test_loss=1.0450, global_test_mse=0.0873
# 		global_train_loss=1.0526, global_train_mse=0.0949
# Time taken for round 69: 00:00:34
# Estimated remaining time: 08:59:16
#
# Round 70: 	 global_test_loss=1.0443, global_test_mse=0.0867
# 		global_train_loss=1.0519, global_train_mse=0.0942
# Time taken for round 70: 00:00:33
# Estimated remaining time: 08:58:26
#
# Round 71: 	 global_test_loss=1.0437, global_test_mse=0.0861
# 		global_train_loss=1.0512, global_train_mse=0.0936
# Time taken for round 71: 00:00:34
# Estimated remaining time: 08:57:43
#
# Round 72: 	 global_test_loss=1.0431, global_test_mse=0.0855
# 		global_train_loss=1.0505, global_train_mse=0.0929
# Time taken for round 72: 00:00:34
# Estimated remaining time: 08:57:01
#
# Round 73: 	 global_test_loss=1.0425, global_test_mse=0.0850
# 		global_train_loss=1.0498, global_train_mse=0.0923
# Time taken for round 73: 00:00:34
# Estimated remaining time: 08:56:21
#
# Round 74: 	 global_test_loss=1.0419, global_test_mse=0.0844
# 		global_train_loss=1.0492, global_train_mse=0.0917
# Time taken for round 74: 00:00:34
# Estimated remaining time: 08:55:42
#
# Round 75: 	 global_test_loss=1.0413, global_test_mse=0.0839
# 		global_train_loss=1.0485, global_train_mse=0.0910
# Time taken for round 75: 00:00:34
# Estimated remaining time: 08:54:59
#
# Round 76: 	 global_test_loss=1.0408, global_test_mse=0.0833
# 		global_train_loss=1.0479, global_train_mse=0.0904
# Time taken for round 76: 00:00:35
# Estimated remaining time: 08:54:31
#
# Round 77: 	 global_test_loss=1.0402, global_test_mse=0.0828
# 		global_train_loss=1.0472, global_train_mse=0.0898
# Time taken for round 77: 00:00:33
# Estimated remaining time: 08:53:41
#
# Round 78: 	 global_test_loss=1.0396, global_test_mse=0.0822
# 		global_train_loss=1.0466, global_train_mse=0.0892
# Time taken for round 78: 00:00:33
# Estimated remaining time: 08:52:57
#
# Round 79: 	 global_test_loss=1.0390, global_test_mse=0.0817
# 		global_train_loss=1.0459, global_train_mse=0.0886
# Time taken for round 79: 00:00:33
# Estimated remaining time: 08:52:13
#
# Round 80: 	 global_test_loss=1.0385, global_test_mse=0.0812
# 		global_train_loss=1.0453, global_train_mse=0.0880
# Time taken for round 80: 00:00:34
# Estimated remaining time: 08:51:31
#
# Round 81: 	 global_test_loss=1.0379, global_test_mse=0.0806
# 		global_train_loss=1.0447, global_train_mse=0.0874
# Time taken for round 81: 00:00:33
# Estimated remaining time: 08:50:47
#
# Round 82: 	 global_test_loss=1.0373, global_test_mse=0.0801
# 		global_train_loss=1.0440, global_train_mse=0.0868
# Time taken for round 82: 00:00:33
# Estimated remaining time: 08:50:00
#
# Round 83: 	 global_test_loss=1.0368, global_test_mse=0.0796
# 		global_train_loss=1.0434, global_train_mse=0.0862
# Time taken for round 83: 00:00:33
# Estimated remaining time: 08:49:15
#
# Round 84: 	 global_test_loss=1.0362, global_test_mse=0.0790
# 		global_train_loss=1.0428, global_train_mse=0.0856
# Time taken for round 84: 00:00:33
# Estimated remaining time: 08:48:25
#
# Round 85: 	 global_test_loss=1.0356, global_test_mse=0.0785
# 		global_train_loss=1.0421, global_train_mse=0.0850
# Time taken for round 85: 00:00:33
# Estimated remaining time: 08:47:39
#
# Round 86: 	 global_test_loss=1.0350, global_test_mse=0.0779
# 		global_train_loss=1.0415, global_train_mse=0.0844
# Time taken for round 86: 00:00:33
# Estimated remaining time: 08:46:53
#
# Round 87: 	 global_test_loss=1.0344, global_test_mse=0.0774
# 		global_train_loss=1.0408, global_train_mse=0.0838
# Time taken for round 87: 00:00:33
# Estimated remaining time: 08:46:07
#
# Round 88: 	 global_test_loss=1.0338, global_test_mse=0.0768
# 		global_train_loss=1.0401, global_train_mse=0.0831
# Time taken for round 88: 00:00:33
# Estimated remaining time: 08:45:24
#
# Round 89: 	 global_test_loss=1.0332, global_test_mse=0.0763
# 		global_train_loss=1.0395, global_train_mse=0.0825
# Time taken for round 89: 00:00:33
# Estimated remaining time: 08:44:39
#
# Round 90: 	 global_test_loss=1.0327, global_test_mse=0.0757
# 		global_train_loss=1.0388, global_train_mse=0.0819
# Time taken for round 90: 00:00:33
# Estimated remaining time: 08:43:54
#
# Round 91: 	 global_test_loss=1.0321, global_test_mse=0.0752
# 		global_train_loss=1.0382, global_train_mse=0.0813
# Time taken for round 91: 00:00:33
# Estimated remaining time: 08:43:10
#
# Round 92: 	 global_test_loss=1.0315, global_test_mse=0.0746
# 		global_train_loss=1.0375, global_train_mse=0.0807
# Time taken for round 92: 00:00:33
# Estimated remaining time: 08:42:27
#
# Round 93: 	 global_test_loss=1.0309, global_test_mse=0.0740
# 		global_train_loss=1.0369, global_train_mse=0.0800
# Time taken for round 93: 00:00:33
# Estimated remaining time: 08:41:43
#
# Round 94: 	 global_test_loss=1.0303, global_test_mse=0.0735
# 		global_train_loss=1.0362, global_train_mse=0.0794
# Time taken for round 94: 00:00:33
# Estimated remaining time: 08:40:56
#
# Round 95: 	 global_test_loss=1.0296, global_test_mse=0.0729
# 		global_train_loss=1.0355, global_train_mse=0.0788
# Time taken for round 95: 00:00:33
# Estimated remaining time: 08:40:14
#
# Round 96: 	 global_test_loss=1.0291, global_test_mse=0.0723
# 		global_train_loss=1.0349, global_train_mse=0.0782
# Time taken for round 96: 00:00:33
# Estimated remaining time: 08:39:31
#
# Round 97: 	 global_test_loss=1.0284, global_test_mse=0.0718
# 		global_train_loss=1.0342, global_train_mse=0.0775
# Time taken for round 97: 00:00:33
# Estimated remaining time: 08:38:50
#
# Round 98: 	 global_test_loss=1.0278, global_test_mse=0.0712
# 		global_train_loss=1.0335, global_train_mse=0.0769
# Time taken for round 98: 00:00:33
# Estimated remaining time: 08:38:07
#
# Round 99: 	 global_test_loss=1.0273, global_test_mse=0.0707
# 		global_train_loss=1.0330, global_train_mse=0.0763
# Time taken for round 99: 00:00:33
# Estimated remaining time: 08:37:28
#
# Round 100: 	 global_test_loss=1.0267, global_test_mse=0.0701
# 		global_train_loss=1.0323, global_train_mse=0.0757
# Time taken for round 100: 00:00:33
# Estimated remaining time: 08:36:45
#
# Round 101: 	 global_test_loss=1.0261, global_test_mse=0.0696
# 		global_train_loss=1.0317, global_train_mse=0.0752
# Time taken for round 101: 00:00:33
# Estimated remaining time: 08:36:00
#
# Round 102: 	 global_test_loss=1.0255, global_test_mse=0.0690
# 		global_train_loss=1.0310, global_train_mse=0.0745
# Time taken for round 102: 00:00:33
# Estimated remaining time: 08:35:19
#
# Round 103: 	 global_test_loss=1.0249, global_test_mse=0.0685
# 		global_train_loss=1.0304, global_train_mse=0.0739
# Time taken for round 103: 00:00:33
# Estimated remaining time: 08:34:38
#
# Round 104: 	 global_test_loss=1.0244, global_test_mse=0.0679
# 		global_train_loss=1.0298, global_train_mse=0.0733
# Time taken for round 104: 00:00:33
# Estimated remaining time: 08:33:58
#
# Round 105: 	 global_test_loss=1.0237, global_test_mse=0.0673
# 		global_train_loss=1.0290, global_train_mse=0.0726
# Time taken for round 105: 00:00:33
# Estimated remaining time: 08:33:16
#
# Round 106: 	 global_test_loss=1.0231, global_test_mse=0.0667
# 		global_train_loss=1.0284, global_train_mse=0.0720
# Time taken for round 106: 00:00:34
# Estimated remaining time: 08:32:39
#
# Round 107: 	 global_test_loss=1.0226, global_test_mse=0.0662
# 		global_train_loss=1.0278, global_train_mse=0.0714
# Time taken for round 107: 00:00:33
# Estimated remaining time: 08:31:59
#
# Round 108: 	 global_test_loss=1.0220, global_test_mse=0.0657
# 		global_train_loss=1.0271, global_train_mse=0.0708
# Time taken for round 108: 00:00:33
# Estimated remaining time: 08:31:15
#
# Round 109: 	 global_test_loss=1.0213, global_test_mse=0.0651
# 		global_train_loss=1.0264, global_train_mse=0.0702
# Time taken for round 109: 00:00:33
# Estimated remaining time: 08:30:37
#
# Round 110: 	 global_test_loss=1.0209, global_test_mse=0.0647
# 		global_train_loss=1.0260, global_train_mse=0.0697
# Time taken for round 110: 00:00:33
# Estimated remaining time: 08:29:55
#
# Round 111: 	 global_test_loss=1.0203, global_test_mse=0.0641
# 		global_train_loss=1.0253, global_train_mse=0.0691
# Time taken for round 111: 00:00:33
# Estimated remaining time: 08:29:16
#
# Round 112: 	 global_test_loss=1.0197, global_test_mse=0.0636
# 		global_train_loss=1.0247, global_train_mse=0.0685
# Time taken for round 112: 00:00:35
# Estimated remaining time: 08:28:47
#
# Round 113: 	 global_test_loss=1.0192, global_test_mse=0.0631
# 		global_train_loss=1.0241, global_train_mse=0.0680
# Time taken for round 113: 00:00:33
# Estimated remaining time: 08:28:08
#
# Round 114: 	 global_test_loss=1.0187, global_test_mse=0.0626
# 		global_train_loss=1.0236, global_train_mse=0.0675
# Time taken for round 114: 00:00:34
# Estimated remaining time: 08:27:34
#
# Round 115: 	 global_test_loss=1.0182, global_test_mse=0.0621
# 		global_train_loss=1.0230, global_train_mse=0.0669
# Time taken for round 115: 00:00:34
# Estimated remaining time: 08:27:04
#
# Round 116: 	 global_test_loss=1.0177, global_test_mse=0.0617
# 		global_train_loss=1.0225, global_train_mse=0.0665
# Time taken for round 116: 00:00:33
# Estimated remaining time: 08:26:27
#
# Round 117: 	 global_test_loss=1.0172, global_test_mse=0.0612
# 		global_train_loss=1.0219, global_train_mse=0.0659
# Time taken for round 117: 00:00:33
# Estimated remaining time: 08:25:47
#
# Round 118: 	 global_test_loss=1.0167, global_test_mse=0.0608
# 		global_train_loss=1.0213, global_train_mse=0.0654
# Time taken for round 118: 00:00:33
# Estimated remaining time: 08:25:09
#
# Round 119: 	 global_test_loss=1.0162, global_test_mse=0.0603
# 		global_train_loss=1.0208, global_train_mse=0.0649
# Time taken for round 119: 00:00:33
# Estimated remaining time: 08:24:28
#
# Round 120: 	 global_test_loss=1.0158, global_test_mse=0.0600
# 		global_train_loss=1.0204, global_train_mse=0.0645
# Time taken for round 120: 00:00:35
# Estimated remaining time: 08:24:03
#
# Round 121: 	 global_test_loss=1.0154, global_test_mse=0.0595
# 		global_train_loss=1.0199, global_train_mse=0.0640
# Time taken for round 121: 00:00:42
# Estimated remaining time: 08:24:28
#
# Round 122: 	 global_test_loss=1.0148, global_test_mse=0.0590
# 		global_train_loss=1.0192, global_train_mse=0.0635
# Time taken for round 122: 00:00:42
# Estimated remaining time: 08:24:53
#
# Round 123: 	 global_test_loss=1.0142, global_test_mse=0.0585
# 		global_train_loss=1.0186, global_train_mse=0.0628
# Time taken for round 123: 00:00:41
# Estimated remaining time: 08:25:06
#
# Round 124: 	 global_test_loss=1.0137, global_test_mse=0.0580
# 		global_train_loss=1.0181, global_train_mse=0.0623
# Time taken for round 124: 00:00:42
# Estimated remaining time: 08:25:28
#
# Round 125: 	 global_test_loss=1.0132, global_test_mse=0.0575
# 		global_train_loss=1.0175, global_train_mse=0.0618
# Time taken for round 125: 00:00:37
# Estimated remaining time: 08:25:13
#
# Round 126: 	 global_test_loss=1.0127, global_test_mse=0.0570
# 		global_train_loss=1.0169, global_train_mse=0.0612
# Time taken for round 126: 00:00:37
# Estimated remaining time: 08:24:57
#
# Round 127: 	 global_test_loss=1.0123, global_test_mse=0.0567
# 		global_train_loss=1.0164, global_train_mse=0.0608
# Time taken for round 127: 00:00:38
# Estimated remaining time: 08:24:48
#
# Round 128: 	 global_test_loss=1.0117, global_test_mse=0.0562
# 		global_train_loss=1.0158, global_train_mse=0.0603
# Time taken for round 128: 00:00:38
# Estimated remaining time: 08:24:39
#
# Round 129: 	 global_test_loss=1.0110, global_test_mse=0.0555
# 		global_train_loss=1.0151, global_train_mse=0.0595
# Time taken for round 129: 00:00:39
# Estimated remaining time: 08:24:37
#
# Round 130: 	 global_test_loss=1.0105, global_test_mse=0.0550
# 		global_train_loss=1.0145, global_train_mse=0.0590
# Time taken for round 130: 00:00:45
# Estimated remaining time: 08:25:17
#
# Round 131: 	 global_test_loss=1.0099, global_test_mse=0.0545
# 		global_train_loss=1.0139, global_train_mse=0.0584
# Time taken for round 131: 00:00:46
# Estimated remaining time: 08:26:02
#
# Round 132: 	 global_test_loss=1.0094, global_test_mse=0.0540
# 		global_train_loss=1.0133, global_train_mse=0.0579
# Time taken for round 132: 00:00:49
# Estimated remaining time: 08:27:00
#
# Round 133: 	 global_test_loss=1.0089, global_test_mse=0.0535
# 		global_train_loss=1.0127, global_train_mse=0.0573
# Time taken for round 133: 00:00:33
# Estimated remaining time: 08:26:14
#
# Round 134: 	 global_test_loss=1.0082, global_test_mse=0.0529
# 		global_train_loss=1.0120, global_train_mse=0.0566
# Time taken for round 134: 00:00:33
# Estimated remaining time: 08:25:29
#
# Round 135: 	 global_test_loss=1.0077, global_test_mse=0.0524
# 		global_train_loss=1.0114, global_train_mse=0.0561
# Time taken for round 135: 00:00:33
# Estimated remaining time: 08:24:43
#
# Round 136: 	 global_test_loss=1.0071, global_test_mse=0.0518
# 		global_train_loss=1.0108, global_train_mse=0.0555
# Time taken for round 136: 00:00:33
# Estimated remaining time: 08:23:56
#
# Round 137: 	 global_test_loss=1.0066, global_test_mse=0.0514
# 		global_train_loss=1.0102, global_train_mse=0.0549
# Time taken for round 137: 00:00:33
# Estimated remaining time: 08:23:10
#
# Round 138: 	 global_test_loss=1.0060, global_test_mse=0.0508
# 		global_train_loss=1.0095, global_train_mse=0.0543
# Time taken for round 138: 00:00:33
# Estimated remaining time: 08:22:25
#
# Round 139: 	 global_test_loss=1.0055, global_test_mse=0.0503
# 		global_train_loss=1.0090, global_train_mse=0.0538
# Time taken for round 139: 00:00:32
# Estimated remaining time: 08:21:37
#
# Round 140: 	 global_test_loss=1.0050, global_test_mse=0.0498
# 		global_train_loss=1.0084, global_train_mse=0.0532
# Time taken for round 140: 00:00:33
# Estimated remaining time: 08:20:53
#
# Round 141: 	 global_test_loss=1.0045, global_test_mse=0.0494
# 		global_train_loss=1.0078, global_train_mse=0.0527
# Time taken for round 141: 00:00:32
# Estimated remaining time: 08:20:05
#
# Round 142: 	 global_test_loss=1.0040, global_test_mse=0.0489
# 		global_train_loss=1.0072, global_train_mse=0.0521
# Time taken for round 142: 00:00:33
# Estimated remaining time: 08:19:19
#
# Round 143: 	 global_test_loss=1.0035, global_test_mse=0.0484
# 		global_train_loss=1.0066, global_train_mse=0.0516
# Time taken for round 143: 00:00:33
# Estimated remaining time: 08:18:36
#
# Round 144: 	 global_test_loss=1.0031, global_test_mse=0.0481
# 		global_train_loss=1.0061, global_train_mse=0.0511
# Time taken for round 144: 00:00:33
# Estimated remaining time: 08:17:52
#
# Round 145: 	 global_test_loss=1.0026, global_test_mse=0.0476
# 		global_train_loss=1.0056, global_train_mse=0.0506
# Time taken for round 145: 00:00:33
# Estimated remaining time: 08:17:08
#
# Round 146: 	 global_test_loss=1.0022, global_test_mse=0.0472
# 		global_train_loss=1.0051, global_train_mse=0.0501
# Time taken for round 146: 00:00:33
# Estimated remaining time: 08:16:24
#
# Round 147: 	 global_test_loss=1.0017, global_test_mse=0.0468
# 		global_train_loss=1.0045, global_train_mse=0.0496
# Time taken for round 147: 00:00:33
# Estimated remaining time: 08:15:42
#
# Round 148: 	 global_test_loss=1.0013, global_test_mse=0.0464
# 		global_train_loss=1.0040, global_train_mse=0.0491
# Time taken for round 148: 00:00:33
# Estimated remaining time: 08:15:00
#
# Round 149: 	 global_test_loss=1.0010, global_test_mse=0.0462
# 		global_train_loss=1.0036, global_train_mse=0.0488
# Time taken for round 149: 00:00:33
# Estimated remaining time: 08:14:20
#
# Round 150: 	 global_test_loss=1.0005, global_test_mse=0.0458
# 		global_train_loss=1.0031, global_train_mse=0.0483
# Time taken for round 150: 00:00:33
# Estimated remaining time: 08:13:37
#
# Round 151: 	 global_test_loss=1.0002, global_test_mse=0.0454
# 		global_train_loss=1.0026, global_train_mse=0.0479
# Time taken for round 151: 00:00:33
# Estimated remaining time: 08:12:53
#
# Round 152: 	 global_test_loss=0.9998, global_test_mse=0.0451
# 		global_train_loss=1.0022, global_train_mse=0.0474
# Time taken for round 152: 00:00:33
# Estimated remaining time: 08:12:13
#
# Round 153: 	 global_test_loss=0.9994, global_test_mse=0.0447
# 		global_train_loss=1.0017, global_train_mse=0.0470
# Time taken for round 153: 00:00:33
# Estimated remaining time: 08:11:31
#
# Round 154: 	 global_test_loss=0.9991, global_test_mse=0.0445
# 		global_train_loss=1.0013, global_train_mse=0.0466
# Time taken for round 154: 00:00:33
# Estimated remaining time: 08:10:48
#
# Round 155: 	 global_test_loss=0.9988, global_test_mse=0.0442
# 		global_train_loss=1.0009, global_train_mse=0.0463
# Time taken for round 155: 00:00:33
# Estimated remaining time: 08:10:06
#
# Round 156: 	 global_test_loss=0.9987, global_test_mse=0.0441
# 		global_train_loss=1.0004, global_train_mse=0.0458
# Time taken for round 156: 00:00:33
# Estimated remaining time: 08:09:25
#
# Round 157: 	 global_test_loss=0.9981, global_test_mse=0.0436
# 		global_train_loss=0.9999, global_train_mse=0.0454
# Time taken for round 157: 00:00:33
# Estimated remaining time: 08:08:42
#
# Round 158: 	 global_test_loss=0.9978, global_test_mse=0.0433
# 		global_train_loss=0.9994, global_train_mse=0.0449
# Time taken for round 158: 00:00:33
# Estimated remaining time: 08:08:01
#
# Round 159: 	 global_test_loss=0.9975, global_test_mse=0.0430
# 		global_train_loss=0.9990, global_train_mse=0.0445
# Time taken for round 159: 00:00:33
# Estimated remaining time: 08:07:19
#
# Round 160: 	 global_test_loss=0.9972, global_test_mse=0.0427
# 		global_train_loss=0.9986, global_train_mse=0.0441
# Time taken for round 160: 00:00:34
# Estimated remaining time: 08:06:41
#
# Round 161: 	 global_test_loss=0.9971, global_test_mse=0.0427
# 		global_train_loss=0.9985, global_train_mse=0.0441
# Time taken for round 161: 00:00:34
# Estimated remaining time: 08:06:05
#
# Round 162: 	 global_test_loss=0.9966, global_test_mse=0.0422
# 		global_train_loss=0.9977, global_train_mse=0.0433
# Time taken for round 162: 00:00:36
# Estimated remaining time: 08:05:39
#
# Round 163: 	 global_test_loss=0.9966, global_test_mse=0.0422
# 		global_train_loss=0.9978, global_train_mse=0.0435
# Time taken for round 163: 00:00:35
# Estimated remaining time: 08:05:09
#
# Round 164: 	 global_test_loss=0.9961, global_test_mse=0.0419
# 		global_train_loss=0.9972, global_train_mse=0.0430
# Time taken for round 164: 00:00:35
# Estimated remaining time: 08:04:39
#
# Round 165: 	 global_test_loss=0.9959, global_test_mse=0.0416
# 		global_train_loss=0.9968, global_train_mse=0.0426
# Time taken for round 165: 00:00:34
# Estimated remaining time: 08:04:05
#
# Round 166: 	 global_test_loss=0.9958, global_test_mse=0.0416
# 		global_train_loss=0.9969, global_train_mse=0.0427
# Time taken for round 166: 00:00:34
# Estimated remaining time: 08:03:29
#
# Round 167: 	 global_test_loss=0.9955, global_test_mse=0.0413
# 		global_train_loss=0.9963, global_train_mse=0.0421
# Time taken for round 167: 00:00:34
# Estimated remaining time: 08:02:55
#
# Round 168: 	 global_test_loss=0.9951, global_test_mse=0.0410
# 		global_train_loss=0.9958, global_train_mse=0.0417
# Time taken for round 168: 00:00:34
# Estimated remaining time: 08:02:21
#
# Round 169: 	 global_test_loss=0.9954, global_test_mse=0.0413
# 		global_train_loss=0.9963, global_train_mse=0.0422
# Time taken for round 169: 00:00:33
# Estimated remaining time: 08:01:42
#
# Round 170: 	 global_test_loss=0.9946, global_test_mse=0.0405
# 		global_train_loss=0.9951, global_train_mse=0.0410
# Time taken for round 170: 00:00:33
# Estimated remaining time: 08:01:02
#
# Round 171: 	 global_test_loss=0.9943, global_test_mse=0.0403
# 		global_train_loss=0.9946, global_train_mse=0.0406
# Time taken for round 171: 00:00:34
# Estimated remaining time: 08:00:26
#
# Round 172: 	 global_test_loss=0.9942, global_test_mse=0.0402
# 		global_train_loss=0.9944, global_train_mse=0.0404
# Time taken for round 172: 00:00:34
# Estimated remaining time: 07:59:50
#
# Round 173: 	 global_test_loss=0.9936, global_test_mse=0.0396
# 		global_train_loss=0.9936, global_train_mse=0.0396
# Time taken for round 173: 00:00:34
# Estimated remaining time: 07:59:14
#
# Round 174: 	 global_test_loss=0.9932, global_test_mse=0.0393
# 		global_train_loss=0.9931, global_train_mse=0.0392
# Time taken for round 174: 00:00:33
# Estimated remaining time: 07:58:36
#
# Round 175: 	 global_test_loss=0.9931, global_test_mse=0.0392
# 		global_train_loss=0.9928, global_train_mse=0.0389
# Time taken for round 175: 00:00:33
# Estimated remaining time: 07:57:57
#
# Round 176: 	 global_test_loss=0.9927, global_test_mse=0.0388
# 		global_train_loss=0.9922, global_train_mse=0.0383
# Time taken for round 176: 00:00:36
# Estimated remaining time: 07:57:30
#
# Round 177: 	 global_test_loss=0.9925, global_test_mse=0.0386
# 		global_train_loss=0.9917, global_train_mse=0.0379
# Time taken for round 177: 00:00:33
# Estimated remaining time: 07:56:51
#
# Round 178: 	 global_test_loss=0.9921, global_test_mse=0.0383
# 		global_train_loss=0.9913, global_train_mse=0.0375
# Time taken for round 178: 00:00:34
# Estimated remaining time: 07:56:13
#
# Round 179: 	 global_test_loss=0.9917, global_test_mse=0.0379
# 		global_train_loss=0.9908, global_train_mse=0.0370
# Time taken for round 179: 00:00:33
# Estimated remaining time: 07:55:32
#
# Round 180: 	 global_test_loss=0.9914, global_test_mse=0.0377
# 		global_train_loss=0.9904, global_train_mse=0.0367
# Time taken for round 180: 00:00:34
# Estimated remaining time: 07:54:55
#
# Round 181: 	 global_test_loss=0.9913, global_test_mse=0.0376
# 		global_train_loss=0.9901, global_train_mse=0.0364
# Time taken for round 181: 00:00:34
# Estimated remaining time: 07:54:17
#
# Round 182: 	 global_test_loss=0.9910, global_test_mse=0.0373
# 		global_train_loss=0.9897, global_train_mse=0.0360
# Time taken for round 182: 00:00:34
# Estimated remaining time: 07:53:40
#
# Round 183: 	 global_test_loss=0.9907, global_test_mse=0.0371
# 		global_train_loss=0.9893, global_train_mse=0.0357
# Time taken for round 183: 00:00:34
# Estimated remaining time: 07:53:03
#
# Round 184: 	 global_test_loss=0.9907, global_test_mse=0.0371
# 		global_train_loss=0.9891, global_train_mse=0.0355
# Time taken for round 184: 00:00:34
# Estimated remaining time: 07:52:25
#
# Round 185: 	 global_test_loss=0.9901, global_test_mse=0.0366
# 		global_train_loss=0.9887, global_train_mse=0.0352
# Time taken for round 185: 00:00:34
# Estimated remaining time: 07:51:47
#
# Round 186: 	 global_test_loss=0.9898, global_test_mse=0.0363
# 		global_train_loss=0.9882, global_train_mse=0.0347
# Time taken for round 186: 00:00:33
# Estimated remaining time: 07:51:09
#
# Round 187: 	 global_test_loss=0.9897, global_test_mse=0.0363
# 		global_train_loss=0.9879, global_train_mse=0.0344
# Time taken for round 187: 00:00:34
# Estimated remaining time: 07:50:32
#
# Round 188: 	 global_test_loss=0.9901, global_test_mse=0.0367
# 		global_train_loss=0.9881, global_train_mse=0.0346
# Time taken for round 188: 00:00:34
# Estimated remaining time: 07:49:56
#
# Round 189: 	 global_test_loss=0.9893, global_test_mse=0.0359
# 		global_train_loss=0.9872, global_train_mse=0.0338
# Time taken for round 189: 00:00:34
# Estimated remaining time: 07:49:20
#
# Round 190: 	 global_test_loss=0.9887, global_test_mse=0.0354
# 		global_train_loss=0.9867, global_train_mse=0.0333
# Time taken for round 190: 00:00:34
# Estimated remaining time: 07:48:43
#
# Round 191: 	 global_test_loss=0.9898, global_test_mse=0.0364
# 		global_train_loss=0.9874, global_train_mse=0.0341
# Time taken for round 191: 00:00:33
# Estimated remaining time: 07:48:04
#
# Round 192: 	 global_test_loss=0.9887, global_test_mse=0.0354
# 		global_train_loss=0.9862, global_train_mse=0.0329
# Time taken for round 192: 00:00:34
# Estimated remaining time: 07:47:27
#
# Round 193: 	 global_test_loss=0.9881, global_test_mse=0.0348
# 		global_train_loss=0.9856, global_train_mse=0.0323
# Time taken for round 193: 00:00:33
# Estimated remaining time: 07:46:49
#
# Round 194: 	 global_test_loss=0.9877, global_test_mse=0.0345
# 		global_train_loss=0.9852, global_train_mse=0.0320
# Time taken for round 194: 00:00:34
# Estimated remaining time: 07:46:13
#
# Round 195: 	 global_test_loss=0.9876, global_test_mse=0.0344
# 		global_train_loss=0.9848, global_train_mse=0.0317
# Time taken for round 195: 00:00:34
# Estimated remaining time: 07:45:36
#
# Round 196: 	 global_test_loss=0.9872, global_test_mse=0.0340
# 		global_train_loss=0.9845, global_train_mse=0.0313
# Time taken for round 196: 00:00:34
# Estimated remaining time: 07:44:59
#
# Round 197: 	 global_test_loss=0.9875, global_test_mse=0.0344
# 		global_train_loss=0.9846, global_train_mse=0.0315
# Time taken for round 197: 00:00:33
# Estimated remaining time: 07:44:21
#
# Round 198: 	 global_test_loss=0.9870, global_test_mse=0.0339
# 		global_train_loss=0.9840, global_train_mse=0.0309
# Time taken for round 198: 00:00:33
# Estimated remaining time: 07:43:42
#
# Round 199: 	 global_test_loss=0.9872, global_test_mse=0.0341
# 		global_train_loss=0.9841, global_train_mse=0.0310
# Time taken for round 199: 00:00:34
# Estimated remaining time: 07:43:04
#
# Round 200: 	 global_test_loss=0.9866, global_test_mse=0.0335
# 		global_train_loss=0.9834, global_train_mse=0.0304
# Time taken for round 200: 00:00:34
# Estimated remaining time: 07:42:27
#
# Round 201: 	 global_test_loss=0.9861, global_test_mse=0.0332
# 		global_train_loss=0.9830, global_train_mse=0.0300
# Time taken for round 201: 00:00:34
# Estimated remaining time: 07:41:50
#
# Round 202: 	 global_test_loss=0.9869, global_test_mse=0.0340
# 		global_train_loss=0.9837, global_train_mse=0.0308
# Time taken for round 202: 00:00:34
# Estimated remaining time: 07:41:13
#
# Round 203: 	 global_test_loss=0.9862, global_test_mse=0.0333
# 		global_train_loss=0.9828, global_train_mse=0.0299
# Time taken for round 203: 00:00:33
# Estimated remaining time: 07:40:34
#
# Round 204: 	 global_test_loss=0.9865, global_test_mse=0.0336
# 		global_train_loss=0.9830, global_train_mse=0.0302
# Time taken for round 204: 00:00:34
# Estimated remaining time: 07:39:59
#
# Round 205: 	 global_test_loss=0.9857, global_test_mse=0.0329
# 		global_train_loss=0.9822, global_train_mse=0.0294
# Time taken for round 205: 00:00:33
# Estimated remaining time: 07:39:20
#
# Round 206: 	 global_test_loss=0.9855, global_test_mse=0.0327
# 		global_train_loss=0.9818, global_train_mse=0.0290
# Time taken for round 206: 00:00:34
# Estimated remaining time: 07:38:45
#
# Round 207: 	 global_test_loss=0.9860, global_test_mse=0.0332
# 		global_train_loss=0.9822, global_train_mse=0.0294
# Time taken for round 207: 00:00:34
# Estimated remaining time: 07:38:09
#
# Round 208: 	 global_test_loss=0.9853, global_test_mse=0.0326
# 		global_train_loss=0.9815, global_train_mse=0.0288
# Time taken for round 208: 00:00:34
# Estimated remaining time: 07:37:35
#
# Round 209: 	 global_test_loss=0.9868, global_test_mse=0.0341
# 		global_train_loss=0.9830, global_train_mse=0.0303
# Time taken for round 209: 00:00:34
# Estimated remaining time: 07:37:00
#
# Round 210: 	 global_test_loss=0.9879, global_test_mse=0.0353
# 		global_train_loss=0.9846, global_train_mse=0.0320
# Time taken for round 210: 00:00:33
# Estimated remaining time: 07:36:22
#
# Round 211: 	 global_test_loss=0.9854, global_test_mse=0.0328
# 		global_train_loss=0.9813, global_train_mse=0.0287
# Time taken for round 211: 00:00:34
# Estimated remaining time: 07:35:46
#
# Round 212: 	 global_test_loss=0.9871, global_test_mse=0.0345
# 		global_train_loss=0.9835, global_train_mse=0.0310
# Time taken for round 212: 00:00:33
# Estimated remaining time: 07:35:09
#
# Round 213: 	 global_test_loss=0.9885, global_test_mse=0.0360
# 		global_train_loss=0.9850, global_train_mse=0.0324
# Time taken for round 213: 00:00:35
# Estimated remaining time: 07:34:37
#
# Round 214: 	 global_test_loss=0.9860, global_test_mse=0.0335
# 		global_train_loss=0.9818, global_train_mse=0.0292
# Time taken for round 214: 00:00:35
# Estimated remaining time: 07:34:04
#
# Round 215: 	 global_test_loss=0.9860, global_test_mse=0.0335
# 		global_train_loss=0.9818, global_train_mse=0.0294
# Time taken for round 215: 00:00:34
# Estimated remaining time: 07:33:29
#
# Round 216: 	 global_test_loss=0.9855, global_test_mse=0.0330
# 		global_train_loss=0.9810, global_train_mse=0.0286
# Time taken for round 216: 00:00:34
# Estimated remaining time: 07:32:56
#
# Round 217: 	 global_test_loss=0.9841, global_test_mse=0.0317
# 		global_train_loss=0.9795, global_train_mse=0.0271
# Time taken for round 217: 00:00:34
# Estimated remaining time: 07:32:21
#
# Round 218: 	 global_test_loss=0.9845, global_test_mse=0.0321
# 		global_train_loss=0.9797, global_train_mse=0.0273
# Time taken for round 218: 00:00:34
# Estimated remaining time: 07:31:47
#
# Round 219: 	 global_test_loss=0.9839, global_test_mse=0.0315
# 		global_train_loss=0.9790, global_train_mse=0.0267
# Time taken for round 219: 00:00:34
# Estimated remaining time: 07:31:10
#
# Round 220: 	 global_test_loss=0.9846, global_test_mse=0.0323
# 		global_train_loss=0.9796, global_train_mse=0.0273
# Time taken for round 220: 00:00:34
# Estimated remaining time: 07:30:36
#
# Round 221: 	 global_test_loss=0.9836, global_test_mse=0.0314
# 		global_train_loss=0.9785, global_train_mse=0.0263
# Time taken for round 221: 00:00:34
# Estimated remaining time: 07:30:00
#
# Round 222: 	 global_test_loss=0.9837, global_test_mse=0.0314
# 		global_train_loss=0.9784, global_train_mse=0.0262
# Time taken for round 222: 00:00:34
# Estimated remaining time: 07:29:25
#
# Round 223: 	 global_test_loss=0.9833, global_test_mse=0.0311
# 		global_train_loss=0.9781, global_train_mse=0.0259
# Time taken for round 223: 00:00:34
# Estimated remaining time: 07:28:49
#
# Round 224: 	 global_test_loss=0.9830, global_test_mse=0.0309
# 		global_train_loss=0.9778, global_train_mse=0.0256
# Time taken for round 224: 00:01:02
# Estimated remaining time: 07:29:51
#
# Round 225: 	 global_test_loss=0.9828, global_test_mse=0.0307
# 		global_train_loss=0.9774, global_train_mse=0.0253
# Time taken for round 225: 00:00:34
# Estimated remaining time: 07:29:17
#
# Round 226: 	 global_test_loss=0.9827, global_test_mse=0.0306
# 		global_train_loss=0.9774, global_train_mse=0.0253
# Time taken for round 226: 00:00:34
# Estimated remaining time: 07:28:41
#
# Round 227: 	 global_test_loss=0.9824, global_test_mse=0.0304
# 		global_train_loss=0.9771, global_train_mse=0.0251
# Time taken for round 227: 00:00:34
# Estimated remaining time: 07:28:06
#
# Round 228: 	 global_test_loss=0.9828, global_test_mse=0.0308
# 		global_train_loss=0.9773, global_train_mse=0.0253
# Time taken for round 228: 00:00:34
# Estimated remaining time: 07:27:31
#
# Round 229: 	 global_test_loss=0.9819, global_test_mse=0.0299
# 		global_train_loss=0.9765, global_train_mse=0.0245
# Time taken for round 229: 00:00:35
# Estimated remaining time: 07:26:58
#
# Round 230: 	 global_test_loss=0.9821, global_test_mse=0.0302
# 		global_train_loss=0.9763, global_train_mse=0.0243
# Time taken for round 230: 00:00:34
# Estimated remaining time: 07:26:23
#
# Round 231: 	 global_test_loss=0.9815, global_test_mse=0.0296
# 		global_train_loss=0.9760, global_train_mse=0.0241
# Time taken for round 231: 00:00:34
# Estimated remaining time: 07:25:49
#
# Round 232: 	 global_test_loss=0.9821, global_test_mse=0.0302
# 		global_train_loss=0.9760, global_train_mse=0.0242
# Time taken for round 232: 00:00:34
# Estimated remaining time: 07:25:13
#
# Round 233: 	 global_test_loss=0.9826, global_test_mse=0.0308
# 		global_train_loss=0.9771, global_train_mse=0.0252
# Time taken for round 233: 00:00:34
# Estimated remaining time: 07:24:38
#
# Round 234: 	 global_test_loss=0.9819, global_test_mse=0.0301
# 		global_train_loss=0.9757, global_train_mse=0.0239
# Time taken for round 234: 00:00:35
# Estimated remaining time: 07:24:05
#
# Round 235: 	 global_test_loss=0.9812, global_test_mse=0.0294
# 		global_train_loss=0.9753, global_train_mse=0.0235
# Time taken for round 235: 00:00:35
# Estimated remaining time: 07:23:31
#
# Round 236: 	 global_test_loss=0.9813, global_test_mse=0.0296
# 		global_train_loss=0.9751, global_train_mse=0.0233
# Time taken for round 236: 00:00:34
# Estimated remaining time: 07:22:56
#
# Round 237: 	 global_test_loss=0.9807, global_test_mse=0.0290
# 		global_train_loss=0.9748, global_train_mse=0.0231
# Time taken for round 237: 00:00:34
# Estimated remaining time: 07:22:20
#
# Round 238: 	 global_test_loss=0.9805, global_test_mse=0.0289
# 		global_train_loss=0.9745, global_train_mse=0.0229
# Time taken for round 238: 00:00:34
# Estimated remaining time: 07:21:44
#
# Round 239: 	 global_test_loss=0.9804, global_test_mse=0.0288
# 		global_train_loss=0.9745, global_train_mse=0.0228
# Time taken for round 239: 00:00:34
# Estimated remaining time: 07:21:09
#
# Round 240: 	 global_test_loss=0.9805, global_test_mse=0.0289
# 		global_train_loss=0.9742, global_train_mse=0.0226
# Time taken for round 240: 00:00:34
# Estimated remaining time: 07:20:34
#
# Round 241: 	 global_test_loss=0.9799, global_test_mse=0.0284
# 		global_train_loss=0.9740, global_train_mse=0.0224
# Time taken for round 241: 00:00:34
# Estimated remaining time: 07:19:58
#
# Round 242: 	 global_test_loss=0.9803, global_test_mse=0.0288
# 		global_train_loss=0.9739, global_train_mse=0.0224
# Time taken for round 242: 00:00:34
# Estimated remaining time: 07:19:23
#
# Round 243: 	 global_test_loss=0.9803, global_test_mse=0.0288
# 		global_train_loss=0.9739, global_train_mse=0.0224
# Time taken for round 243: 00:00:34
# Estimated remaining time: 07:18:48
#
# Round 244: 	 global_test_loss=0.9804, global_test_mse=0.0289
# 		global_train_loss=0.9747, global_train_mse=0.0232
# Time taken for round 244: 00:00:34
# Estimated remaining time: 07:18:11
#
# Round 245: 	 global_test_loss=0.9802, global_test_mse=0.0288
# 		global_train_loss=0.9737, global_train_mse=0.0223
# Time taken for round 245: 00:00:34
# Estimated remaining time: 07:17:36
#
# Round 246: 	 global_test_loss=0.9801, global_test_mse=0.0287
# 		global_train_loss=0.9736, global_train_mse=0.0222
# Time taken for round 246: 00:00:34
# Estimated remaining time: 07:16:59
#
# Round 247: 	 global_test_loss=0.9797, global_test_mse=0.0284
# 		global_train_loss=0.9732, global_train_mse=0.0219
# Time taken for round 247: 00:00:34
# Estimated remaining time: 07:16:24
#
# Round 248: 	 global_test_loss=0.9793, global_test_mse=0.0280
# 		global_train_loss=0.9728, global_train_mse=0.0215
# Time taken for round 248: 00:00:34
# Estimated remaining time: 07:15:50
#
# Round 249: 	 global_test_loss=0.9793, global_test_mse=0.0281
# 		global_train_loss=0.9727, global_train_mse=0.0214
# Time taken for round 249: 00:00:34
# Estimated remaining time: 07:15:15
#
# Round 250: 	 global_test_loss=0.9793, global_test_mse=0.0281
# 		global_train_loss=0.9726, global_train_mse=0.0214
# Time taken for round 250: 00:00:34
# Estimated remaining time: 07:14:40
#
# Round 251: 	 global_test_loss=0.9790, global_test_mse=0.0278
# 		global_train_loss=0.9724, global_train_mse=0.0212
# Time taken for round 251: 00:00:34
# Estimated remaining time: 07:14:05
#
# Round 252: 	 global_test_loss=0.9800, global_test_mse=0.0288
# 		global_train_loss=0.9733, global_train_mse=0.0221
# Time taken for round 252: 00:00:34
# Estimated remaining time: 07:13:29
#
# Round 253: 	 global_test_loss=0.9785, global_test_mse=0.0274
# 		global_train_loss=0.9720, global_train_mse=0.0209
# Time taken for round 253: 00:00:34
# Estimated remaining time: 07:12:53
#
# Round 254: 	 global_test_loss=0.9787, global_test_mse=0.0276
# 		global_train_loss=0.9720, global_train_mse=0.0209
# Time taken for round 254: 00:00:34
# Estimated remaining time: 07:12:17
#
# Round 255: 	 global_test_loss=0.9785, global_test_mse=0.0275
# 		global_train_loss=0.9718, global_train_mse=0.0207
# Time taken for round 255: 00:00:34
# Estimated remaining time: 07:11:42
#
# Round 256: 	 global_test_loss=0.9782, global_test_mse=0.0272
# 		global_train_loss=0.9716, global_train_mse=0.0206
# Time taken for round 256: 00:00:34
# Estimated remaining time: 07:11:07
#
# Round 257: 	 global_test_loss=0.9782, global_test_mse=0.0272
# 		global_train_loss=0.9714, global_train_mse=0.0204
# Time taken for round 257: 00:00:34
# Estimated remaining time: 07:10:31
#
# Round 258: 	 global_test_loss=0.9780, global_test_mse=0.0270
# 		global_train_loss=0.9713, global_train_mse=0.0203
# Time taken for round 258: 00:00:34
# Estimated remaining time: 07:09:55
#
# Round 259: 	 global_test_loss=0.9775, global_test_mse=0.0266
# 		global_train_loss=0.9710, global_train_mse=0.0201
# Time taken for round 259: 00:00:34
# Estimated remaining time: 07:09:20
#
# Round 260: 	 global_test_loss=0.9778, global_test_mse=0.0269
# 		global_train_loss=0.9710, global_train_mse=0.0201
# Time taken for round 260: 00:00:34
# Estimated remaining time: 07:08:44
#
# Round 261: 	 global_test_loss=0.9772, global_test_mse=0.0263
# ...
# Estimated remaining time: 05:45:16
#
# Round 408: 	 global_test_loss=0.9665, global_test_mse=0.0209
# 		global_train_loss=0.9582, global_train_mse=0.0126
# Time taken for round 408: 00:00:34
# Estimated remaining time: 05:44:41
#
# Round 409: 	 global_test_loss=0.9658, global_test_mse=0.0202
# 		global_train_loss=0.9579, global_train_mse=0.0123
# Time taken for round 409: 00:00:56
# Estimated remaining time: 05:44:37
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
#
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
#
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "<ipython-input-42-164aa9feee54>", line 31, in <cell line: 18>
#     global_train_loss, global_train_mse = h3_eval.evaluate(regress_train_central, verbose=0)
#   File "/usr/local/lib/python3.10/dist-packages/keras/utils/traceback_utils.py", line 70, in error_handler
#     raise e.with_traceback(filtered_tb) from None
#   File "/usr/lib/python3.10/traceback.py", line 39, in format_list
#     return StackSummary.from_list(extracted_list).format()
#   File "/usr/lib/python3.10/traceback.py", line 401, in from_list
#     filename, lineno, name, line = frame
#   File "/usr/lib/python3.10/inspect.py", line 861, in getmodule
#     file = getabsfile(object, _filename)
#   File "/usr/lib/python3.10/inspect.py", line 845, in getabsfile
#     return os.path.normcase(os.path.abspath(_filename))
#   File "/usr/lib/python3.10/posixpath.py", line 384, in abspath
#     cwd = os.getcwd()
# OSError: [Errno 107] Transport endpoint is not connected
#
# During handling of the above exception, another exception occurred:
#
# OSError: [Errno 107] Transport endpoint is not connected
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3553, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-42-164aa9feee54>", line 18, in <cell line: 18>
#     with open(csv_file_path, 'w', newline='') as csv_file:
# OSError: [Errno 107] Transport endpoint is not connected
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 2099, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'OSError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1101, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 248, in wrapped
#     return f(*args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 281, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "/usr/lib/python3.10/inspect.py", line 1662, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "/usr/lib/python3.10/inspect.py", line 1620, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "/usr/lib/python3.10/inspect.py", line 829, in getsourcefile
#     module = getmodule(object, filename)
#   File "/usr/lib/python3.10/inspect.py", line 861, in getmodule
#     file = getabsfile(object, _filename)
#   File "/usr/lib/python3.10/inspect.py", line 845, in getabsfile
#     return os.path.normcase(os.path.abspath(_filename))
#   File "/usr/lib/python3.10/posixpath.py", line 384, in abspath
#     cwd = os.getcwd()
# OSError: [Errno 107] Transport endpoint is not connected
# Traceback (most recent call last):
#   File "<ipython-input-42-164aa9feee54>", line 31, in <cell line: 18>
#     global_train_loss, global_train_mse = h3_eval.evaluate(regress_train_central, verbose=0)
#   File "/usr/local/lib/python3.10/dist-packages/keras/utils/traceback_utils.py", line 70, in error_handler
#     raise e.with_traceback(filtered_tb) from None
#   File "/usr/lib/python3.10/traceback.py", line 39, in format_list
#     return StackSummary.from_list(extracted_list).format()
#   File "/usr/lib/python3.10/traceback.py", line 401, in from_list
#     filename, lineno, name, line = frame
#   File "/usr/lib/python3.10/inspect.py", line 861, in getmodule
#     file = getabsfile(object, _filename)
#   File "/usr/lib/python3.10/inspect.py", line 845, in getabsfile
#     return os.path.normcase(os.path.abspath(_filename))
#   File "/usr/lib/python3.10/posixpath.py", line 384, in abspath
#     cwd = os.getcwd()
# OSError: [Errno 107] Transport endpoint is not connected
#
# During handling of the above exception, another exception occurred:
#
# OSError: [Errno 107] Transport endpoint is not connected
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3553, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-42-164aa9feee54>", line 18, in <cell line: 18>
#     with open(csv_file_path, 'w', newline='') as csv_file:
# OSError: [Errno 107] Transport endpoint is not connected
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 2099, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'OSError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3473, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3575, in run_code
#     self.showtraceback(running_compiled_code=True)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 2101, in showtraceback
#     stb = self.InteractiveTB.structured_traceback(etype,
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1367, in structured_traceback
#     return FormattedTB.structured_traceback(
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1267, in structured_traceback
#     return VerboseTB.structured_traceback(
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1124, in structured_traceback
#     formatted_exception = self.format_exception_as_a_whole(etype, evalue, etb, number_of_lines_of_context,
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1082, in format_exception_as_a_whole
#     last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 382, in find_recursion
#     return len(records), 0
# TypeError: object of type 'NoneType' has no len()
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 2099, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'TypeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1101, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 248, in wrapped
#     return f(*args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 281, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "/usr/lib/python3.10/inspect.py", line 1662, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "/usr/lib/python3.10/inspect.py", line 1620, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "/usr/lib/python3.10/inspect.py", line 829, in getsourcefile
#     module = getmodule(object, filename)
#   File "/usr/lib/python3.10/inspect.py", line 861, in getmodule
#     file = getabsfile(object, _filename)
#   File "/usr/lib/python3.10/inspect.py", line 845, in getabsfile
#     return os.path.normcase(os.path.abspath(_filename))
#   File "/usr/lib/python3.10/posixpath.py", line 384, in abspath
#     cwd = os.getcwd()
# OSError: [Errno 107] Transport endpoint is not connected
# Traceback (most recent call last):
#   File "<ipython-input-42-164aa9feee54>", line 31, in <cell line: 18>
#     global_train_loss, global_train_mse = h3_eval.evaluate(regress_train_central, verbose=0)
#   File "/usr/local/lib/python3.10/dist-packages/keras/utils/traceback_utils.py", line 70, in error_handler
#     raise e.with_traceback(filtered_tb) from None
#   File "/usr/lib/python3.10/traceback.py", line 39, in format_list
#     return StackSummary.from_list(extracted_list).format()
#   File "/usr/lib/python3.10/traceback.py", line 401, in from_list
#     filename, lineno, name, line = frame
#   File "/usr/lib/python3.10/inspect.py", line 861, in getmodule
#     file = getabsfile(object, _filename)
#   File "/usr/lib/python3.10/inspect.py", line 845, in getabsfile
#     return os.path.normcase(os.path.abspath(_filename))
#   File "/usr/lib/python3.10/posixpath.py", line 384, in abspath
#     cwd = os.getcwd()
# OSError: [Errno 107] Transport endpoint is not connected
#
# During handling of the above exception, another exception occurred:
#
# OSError: [Errno 107] Transport endpoint is not connected
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3553, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-42-164aa9feee54>", line 18, in <cell line: 18>
#     with open(csv_file_path, 'w', newline='') as csv_file:
# OSError: [Errno 107] Transport endpoint is not connected
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 2099, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'OSError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3473, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3575, in run_code
#     self.showtraceback(running_compiled_code=True)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 2101, in showtraceback
#     stb = self.InteractiveTB.structured_traceback(etype,
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1367, in structured_traceback
#     return FormattedTB.structured_traceback(
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1267, in structured_traceback
#     return VerboseTB.structured_traceback(
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1124, in structured_traceback
#     formatted_exception = self.format_exception_as_a_whole(etype, evalue, etb, number_of_lines_of_context,
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1082, in format_exception_as_a_whole
#     last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 382, in find_recursion
#     return len(records), 0
# TypeError: object of type 'NoneType' has no len()
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 2099, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'TypeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3030, in _run_cell
#     return runner(coro)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/async_helpers.py", line 78, in _pseudo_sync_runner
#     coro.send(None)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3257, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3492, in run_ast_nodes
#     self.showtraceback()
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 2101, in showtraceback
#     stb = self.InteractiveTB.structured_traceback(etype,
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1367, in structured_traceback
#     return FormattedTB.structured_traceback(
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1267, in structured_traceback
#     return VerboseTB.structured_traceback(
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1142, in structured_traceback
#     formatted_exceptions += self.format_exception_as_a_whole(etype, evalue, etb, lines_of_context,
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1082, in format_exception_as_a_whole
#     last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 382, in find_recursion
#     return len(records), 0
# TypeError: object of type 'NoneType' has no len()
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 2099, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'TypeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 1101, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 248, in wrapped
#     return f(*args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py", line 281, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "/usr/lib/python3.10/inspect.py", line 1662, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "/usr/lib/python3.10/inspect.py", line 1620, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "/usr/lib/python3.10/inspect.py", line 829, in getsourcefile
#     module = getmodule(object, filename)
#   File "/usr/lib/python3.10/inspect.py", line 861, in getmodule
#     file = getabsfile(object, _filename)
#   File "/usr/lib/python3.10/inspect.py", line 845, in getabsfile
#     return os.path.normcase(os.path.abspath(_filename))
#   File "/usr/lib/python3.10/posixpath.py", line 384, in abspath
#     cwd = os.getcwd()
# OSError: [Errno 107] Transport endpoint is not connected

# %% [markdown]
# ## Evaluation and Finishing Up

# %%
h3_eval.set_weights(server_state_h3)
h3_eval.evaluate(regress_test_central)

# %%
h3_eval.save('Models/' + MODEL_NAME + '.h5')

# %%
from google.colab import runtime
runtime.unassign()
